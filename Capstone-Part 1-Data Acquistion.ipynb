# %% [markdown]
# # Capstone Project - <i>"He Got Game So Show Him The Money"</i>
#
# ## Problem Statement
#
# Player/agent negotiations with teams have the potential to be contentious which can cause anxiety to the player, team management as well as the fanbase. Time, energy and money are all at stake during contract negotiations so it would be of great benefit to have a means of accelerating this process by having a regression model that is agnostic to any biases and present a fair contract amount based on anticipated player production. Performance will be guided by r2 score. Baseline is the mean salary.
#
# ### Contents:
# #### Part 1:
# - [Methodology](#Methodology)
# - [Data Acquisition](#Data-Acquisition)
#
# ### Methodology
#
# I will use the NBA historical stats dataset from Kaggle and merge it with scraped salary information from hoopshype.com. I will begin with 10 years of data (2007-2017) which covers a decade of data that includes the last update of the NBA historical stats dataset. Once assembled, I will search for outliers for salary compared to winshares (WS) as well as minutes played. This should also remove outliers due to injury.
#
# I will then scale the results as part of preprocessing and encode the position before checking for correlation and adding possible interaction terms. I will then set up train/test splits for modelling with an initial test size of 0.3.
#
# I expect few incomplete records due to the quality of the source for the dataset (basketball-reference.com). I am cognizant that the author of the dataset may not have compiled everything without omissions. Additional challenges are that players that were traded during the season will have multiple rows which will need to be removed. I will use the 'TOT' row for that player instead which will contain the entire season's production. Some additional features that are available that haven't been added include player details (eg. which college they attended, height, weight, etc) will be considered for addition based on the initial model performance.
#
# A major assumption is that we will only predict a single year's salary for our output. This may cause issues as contracts can run for multiple years which is beyond the scope of this project. Additionally, features such as "Bird Rights" and various salary cap exceptions will not be considered as these features are generally not widely tracked in NBA statistical databases.
#
# The regressors I intend to use are Linear, Lasso, Ridge, Random Forest and SVR. Time permitting, I will also add in a neural network.

# %% [markdown]
# ## Package Import

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# ### Test Webscrape With 2020 Salaries

# %%
url = "https://hoopshype.com/salaries/players/" #this is the only year that does not correspond with the site's convention of page naming for player salaries
req = requests.get(url)
req.status_code
# Out:
# 200

# %%
html = req.text
soup = BeautifulSoup(html, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="no-js ie-browser lt-ie9"> <![endif]--><!--[if IE 9]> <html lang="en" class="no-js ie-browser ie9"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <script>(function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement)</script>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://hoopshype.com/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
#     <script src="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/js/lib/html5.js" type="text/javascript"></script>
# 	<link rel="stylesheet" type="text/css" href="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/ie8.css">
# 	<![endif]-->
# <!--[if gte IE 9]>
# 	<link rel="stylesheet" type="text/css" href="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/ie9.css">
# 	<![endif]-->
# <meta content="Hoopshype salaries of all NBA players" name="description"/>
# <meta content="lue-lebron dynamic, showbusiness, fashiob, wnba, sponsored, obituary, all-star contests, timeline, hoopshype trivia, like, top gear, qa category, rosters, betting, quiz, scott-randle dynamic, payroll, d-league, depth charts, pistons" name="keywords"/>
# <title>NBA Player Salaries | HoopsHype</title>
# <script type="text/javascript">!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://fuzzybasketball.com/v2gowqTzhmRSoHingsdyT7hJbLj3e0evd8xJXkobyuVOqAKVqZLBte2XUwS5VNVDH",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");</script><meta content="vjU_CGncz37FseIKJKx118S7FcYlPjyIGG9aFD-Mno8" name="google-site-verification"/>
# <meta content="6C7AFE373C691E833D6444FFA7F6E8A2" name="msvalidate.01"/>
# <script src="https://r-login.wordpress.com/remote-login.php?action=js&amp;host=hoopshype.com&amp;id=85827622&amp;t=1589322885&amp;back=https%3A%2F%2Fhoopshype.com%2Fsalaries%2Fplayers%2F" type="text/javascript"></script>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 			if ( 'function' === typeof WPRemoteLogin ) {
# 				document.cookie = "wordpress_test_cookie=test; path=/";
# 				if ( document.cookie.match( /(;|^)\s*wordpress_test_cookie\=/ ) ) {
# 					WPRemoteLogin();
# 				}
# 			}
# 		/* ]]> */
# 		</script>
# <link href="//s1.wp.com" rel="dns-prefetch"/>
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//native.sharethrough.com" rel="dns-prefetch"/>
# <link href="//js-sec.indexww.com" rel="dns-prefetch"/>
# <link href="//cdn.adsafeprotected.com" rel="dns-prefetch"/>
# <link href="//www.gannett-cdn.com" rel="dns-prefetch"/>
# <link href="//confiant-integrations.global.ssl.fastly.net" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//run.adrizer.com" rel="dns-prefetch"/>
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//cdn.onesignal.com" rel="dns-prefetch"/>
# <link href="//usathoopshype.wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://hoopshype.com/feed/" rel="alternate" title="HoopsHype » Feed" type="application/rss+xml"/>
# <link href="https://hoopshype.com/comments/feed/" rel="alternate" title="HoopsHype » Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s2.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1582709031h&ver=5.4.1"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s0.wp.com/_static/??-eJx9UNEKwjAM/CFrmSBuD+K3rG2c0aYtTcrs31s32IPIXsLluMtx0XNSNgaBIJqKSr5MGFjPyUZSTOih/mxHy3zQ/20Y7hhQ6gY2MQbriwPWjdAOWbTx0b6UR5PHXDVL9XAkDHvnbczQeEqjfBUEDkfwQE22Z5vRTSBr9IqVwHvfsjQ2JmVgVm0SFlLyaFnLA2507c79ZRhOXd89P/n1ejM=?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="//cdnjs.cloudflare.com/ajax/libs/galleria/1.4.2/themes/classic/galleria.classic.css?ver=1.4.2" id="galleria-theme-css" media="all" rel="stylesheet"/>
# <link href="https://s0.wp.com/_static/??-?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Ubuntu:300,400,500,700" id="google-fonts-ubuntu-css" media="all" rel="stylesheet"/>
# <link href="https://s0.wp.com/wp-content/themes/h4/global.css?m=1420737423h&amp;cssminify=yes" id="all-css-4-1" media="all" rel="stylesheet" type="text/css"/>
# <script>var googletag_cmd_push = function(o){ return googletag.cmd.push( o ); };</script><script>
# var amznAcctId = ["3090"];
# </script>
# <script type="text/javascript">
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");window.bidSlots=window.bidSlots||[];window._mweb=0;apstag.init({pubID: amznAcctId[0], adServer: "googletag"});
# </script>
# <script src="https://s1.wp.com/_static/??-eJx9jUEOwiAQRS8kRReYujCehcJYIcyAzNCmt5cmujHGZJK/+O+/0WtRgVxqHljHfs8GdXvHEPmg/wEKw1ytwICBPrDLJECysyWzIDDbGX60mKeQQDWG2gGS/uaevzl5QDfoJRTd2Er2dlPJrhXIwS6ZgvdQFVrqjtrXN7yezDhejDmeTXwB2OBSfQ==" type="text/javascript"></script>
# <script src="https://js-sec.indexww.com/ht/p/184031-126856402220676.js?ver=5.4.1"></script>
# <script src="https://cdn.adsafeprotected.com/iasPET.1.js?ver=5.4.1"></script>
# <script>
# var iasDataHandler, __iasPET = __iasPET || {};
# 				__iasPET.queue = __iasPET.queue || [];
# 				__iasPETSlots = [];
# 				__iasPET.pubId = '922805';
# 				bidManager.addBidder( 'ias' );
#
# </script>
# <script>
# var gciDataLayer = {"event-type":"pageview","page-market-name":"smg","page-blogname":"hoopshype","page-has-video":"","page-use-canonical":"1","content-ssts-section":"sports","content-ssts-subsection":"sports:hoopshype","content-ssts-topic":"sports:hoopshype","content-ssts-subtopic":"sports:hoopshype","page-experience-type":"desktop","content-type":"homefront"};
# </script>
# <script>
# 			window.gciAnalyticsUAID = "SMG-TEALIUM-HOOPSHYPE";
# 			gciDataLayer["page-full-url"] = window.location.href;
# 			gciDataLayer["content-name"] = window.location.pathname;
#
#
# 			var stateManager = {
# 				getActivePageInfo: function() {
# 					return {
# 						byline: gciDataLayer["content-byline"] || "",
# 						contentHeadline: gciDataLayer["content-headline"] || "",
# 						contentId: gciDataLayer["content-id"] || "",
# 						taxonomykeywords: gciDataLayer["content-keywords"] || "",
# 						contentType: gciDataLayer["content-type"] || "",
# 						cst: gciDataLayer["cst"] || "",
# 						pageHasVideo: (gciDataLayer["page-has-video"]) ? gciDataLayer["page-has-video"].toLowerCase() : "",
# 						ssts: gciDataLayer["content-ssts-subtopic"] || "",
# 					}
# 				}
# 			}
#
# </script>
# <script src="https://www.gannett-cdn.com/dcjs/prod/main.js?ver=1"></script>
# <script>
# 			document.addEventListener("gciAnalyticsReady", function () {
# 				window.gciAnalytics.view(gciDataLayer);
# 			} );
#
# </script>
# <script src="https://s0.wp.com/wp-content/themes/vip/usatoday-lawrence/modules/brightcove/js/tealium-brightcove.js?m=1500922554h" type="text/javascript"></script>
# <script>
# var lawrence_ad_marketplace_data = {"endpoint":"","suggest_endpoint":"https:\/\/usatoday_cps.cps.ampfeed.com\/suggestions?partner=usatoday_cps&sub1=nba&sub2=hoopshype.com&sub3=paidsuggest&v=1.1&callback=1589322885&out=json","sponsored_text":"Sponsored","ads_by_text":"Ads by adMarketplace"};
# </script>
# <script src="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/modules/ad-marketplace/js/sponsored-search-results.js?m=1568040173h&amp;ver=1.0.0"></script>
# <script async="" src="https://confiant-integrations.global.ssl.fastly.net/FvW3szAY_s729BZEa4_yfA6omyQ/gpt_and_prebid/config.js?ver=1.0.0"></script>
# <script>
# var usatoday_gallery_ajax_object = {"publisherGA":"UA-5226424-1","sharethispubid":"fd7eb3e3-60ab-4eeb-9e7b-cb89e8ec8c83"};
# var _usmgOptions = {"ipdir":"r","gaid":"UA-5226424-1","dfpid":"","pid":"SMG_HoopsHype","ads":[],"tlmurl":"https:\/\/tags.tiqcdn.com\/utag\/gci\/hoopshype\/prod\/utag.js"};
# </script>
# <script src="https://s2.wp.com/_static/??-eJylkNEOgjAMRX/I0QxCfDJ+S4WCHduYdAP5e0eiJr5BfGt6e07awhJUM/pIPkK8kyOBmQMkwTi2uKpgU89eAAOrHq2lifMIilAUMAKR0HJy72wtjJzgT2WSNuT+kiM166Lc47S4TOQb2ngZOCjLflDd2CRRHT+PKswjbcc4ZH8UtXz74BK5GXa95Gd9bqevIdeZv7qLrvW5qkutK/MCzHqjVw==" type="text/javascript"></script>
# <script data-domain="hoopshype.com" id="ADRIZER_JS" src="//run.adrizer.com/track.js?ver=5.4.1" type="text/javascript"></script><script src="https://s0.wp.com/_static/??-eJx1i8EKwjAQRH9Iu6SWiAfxW2yylSxxEzuJwb+3lHopeBpm3jxq+RjUxeoZJCDkoJ3gQLtdXpXnzxbdvxfalEZhV37QJS2shXKsj6Cgd/Cc6A5wWYW155mBxbg9r2boT2drTX+RL29QOFo=" type="text/javascript"></script>
# <link href="https://usathoopshype.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://wp.me/5O7Gu" rel="shortlink"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="These are the  salaries of all NBA players" property="og:title"/>
# <meta content="Hoopshype  salaries of all NBA players" property="og:description"/>
# <meta content="https://hoopshype.com/salaries/players/" property="og:url"/>
# <meta content="HoopsHype" property="og:site_name"/>
# <meta content="https://usathoopshype.files.wordpress.com/2017/01/logo-hoopshype-header.png" property="og:image"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="@hoopshype" name="twitter:site"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://secure.gravatar.com/blavatar/8195f692d09575689011557b84764b61?s=32" rel="shortcut icon" sizes="16x16" type="image/x-icon"/>
# <link href="https://secure.gravatar.com/blavatar/8195f692d09575689011557b84764b61?s=32" rel="icon" sizes="16x16" type="image/x-icon"/>
# <link href="https://secure.gravatar.com/blavatar/8195f692d09575689011557b84764b61?s=114" rel="apple-touch-icon"/>
# <link href="https://hoopshype.com/?openidserver=1" rel="openid.server"/>
# <link href="https://hoopshype.com/" rel="openid.delegate"/>
# <link href="https://hoopshype.com/osd.xml" rel="search" title="HoopsHype" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="false" name="gdpr"/>
# <script type="application/ld+json">
# 	{
# 		"@context": "http://schema.org",
# 		"@type": "WebPage",
# 		"url": "https://hoopshype.com",
# 		"headline": "HoopsHype",
# 	}
# </script>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script><link href="/manifest.json" rel="manifest"/><style type="text/css">
# .articleBody a,
# .article__pagination a,
# .author__description a,
# .search-no-results .entry-content a,
# .archive-no-results .entry-content a,
# .nav__item--parent > a:after,
# .nav__item--podcast .nav__item-link,
# .mobile-nav__item--podcast .mobile-nav__item-link,
# .mobile-nav__footer-menu .mobile-nav__item a:active,
# .trending__item:before,
# .trending__link,
# .hero__shares,
# .column h3 > a:hover,
# .second-tab-content p > a:hover,
# .single-related p > a:hover,
# .widget--box .text-block a:hover,
# .widget--section-promo p > a:hover,
# .column .meta-info a,
# .zone--video .medium .author a,
# .block--hero .reply-block,
# .social-cta__button,
# .social-cta__notice--error,
# #footer-info .togglee a:hover,
# #footer-info .togglee a:active,
# .article__subheading,
# .articleBody h2,
# .search-no-results .entry-content h2,
# .archive-no-results .entry-content h2,
# .article__author a,
# .author__twitter a,
# .articleBody .pq,
# .search-no-results .entry-content .pq,
# .archive-no-results .entry-content .pq,
# .single-related .block__shares,
# .widget--section-promo .block__shares,
# .article__back:before,
# .article__back:hover,
# .archive .heading .taxonomy,
# .search-results .heading .taxonomy,
# .search-results .heading > span,
# .archive.author .heading h1 a,
# .widget_text .textwidget a,
# .sidebar-upper .widget_usat_sidebar_top_posts_widget .text-block > h2,
# .sidebar-upper .widget_usat_sidebar_top_posts_widget .text-block > h2 > a,
# .sidebar-upper .widget_usat_sidebar_top_posts_widget .text-block .shares,
# .widget--box .text-block > h2,
# .widget--box .text-block > h2 > a,
# .widget--author a,
# .newsletter-close-alt a,
# .related .block__title:hover,
# .hero__secondary .hero__link:hover .hero__title,
# .widget_usat_sidebar_top_posts_widget .reply-block .social-count,
# .ad-marketplace-search-result-link {
# 	color: #eb1e00;
# }
#
# .mobile-stream-tabs h2,
# .column .heading-small h2,
# .sidebar-upper .widget .heading-small h2,
# .single-related .heading-small h2,
# #video-container .heading-small h2,
# .mobile-stream-tabs > div {
# 	border-bottom-color: #eb1e00;
# }
#
# @media all and (min-width: 1000px) {
# 	.branding__logo-link {
# 		border-bottom-color: #eb1e00;
# 	}
# }
#
# .article__pagination .article__pagination__button:hover,
# .article__pagination .article__pagination__link:hover,
# .article__pagination .article__pagination__button:active,
# .article__pagination .article__pagination__link:active {
# 	border-color: #eb1e00;
# }
#
# .nav__item:hover,
# .nav__item--current,
# #footer-info,
# .ad-marketplace-sponsored-text {
# 	border-top-color: #eb1e00;
# }
#
# .articleBody blockquote:not(.pq),
# .search-no-results .entry-content blockquote:not(.pq),
# .archive-no-results .entry-content blockquote:not(.pq) {
# 	border-left-color: #eb1e00;
# }
#
# .newsletter-modal {
# 	border-top: solid 8px #eb1e00;
# }
#
# .article__back {
# 	border-color: #eb1e00;
# }
#
# .vertical-gallery--icon,
# .smg-event--icon,
# .vertical-gallery__overlay,
# .hero__label,
# .column .block .img-holder .meta,
# .second-tab-content h2,
# .single-related .fixed-height-img-holder.link .meta,
# .mobile-nav__menu .mobile-nav__item > a:active,
# .mobile-nav__menu .mobile-nav__item--current > a,
# .article__pagination__current,
# .articleBody:after,
# .search-no-results .entry-content:after,
# .archive-no-results .entry-content:after,
# .story-share-buttons .share-count,
# .daily-newsletter__button {
# 	background-color: #eb1e00;
# }
#
# .newsletter__button {
# 	background-image: linear-gradient(to bottom, rgba(0, 0, 0, 0), rgba(0, 0, 0, 0.12)),
# 		linear-gradient(#eb1e00, #eb1e00)
# }
#
# .newsletter__button:after,
# .daily-newsletter__button:after {
# 	background-color: #eb1e00;
# }
#
# @media all and (min-width: 1000px) {
# 	.branding {
# 		border-bottom-color: #eb1e00;
# 	}
# }
#
# .smg-event__ctabutton {
# 	background-color: #eb1e00;
# 	box-shadow: 0 2px 0 0 #eb1e00;
# }
# </style>
# <link href="https://hoopshype.com" rel="canonical"/>
# <style>
# 			.wpcom-related-posts ul li {
# 				list-style-type: none;
# 				display: inline-block;
# 			}
# 		</style>
# <style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# <meta content="HoopsHype" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="name=Subscribe;action-uri=https://hoopshype.com/feed/;icon-uri=https://secure.gravatar.com/blavatar/8195f692d09575689011557b84764b61?s=16" name="msapplication-task"/>
# <!-- Include google_services.js -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
# 	var bottomAdMobileRendered = false,
# 		googletag = googletag || {},
# 		bidTimeout;
# 	googletag.cmd = googletag.cmd || [];
# 	bidManager.timeout = 2500;
# 	bidManager.addBidder('a9');
# 	</script>
# <!-- helper function for targeting the url -->
# <script type="text/javascript">
# (function(e,t){function i(){e.googletag=e.googletag||{};e.sdpTargeting=this.urlTargeting();e._sitePage=e.sdpTargeting.sp}var n,r;i.prototype.urlTargeting=function(){var t=e.location.pathname.replace(/\/$/,""),n=new RegExp("/([^/]*)","ig"),r=t.match(n),i=["/"],s="";if(r&&t!=="/"){var o="",u=r.length;if(u>0){for(var a=0;a<u;a++){o=r[a];i.push(o);for(var f=a+1;f<u;f++){o+=r[f];i.push(o)}if(a===0){i.splice(-1,1);s=o}}}i.push(s)}i=i.reverse();var l=e.location.toString().replace(/\=/ig,":").match(/\?(.+)$/),c=RegExp.$1.split("&"),h=e.location.toString().replace(/\/*(\?|\&|\x26)*(\w+=\w+)*$/,"");var p=h.replace(/http:\/\//,"").split("/");var d=p.length==1?"main":p[1].match(/^$|^index\.(php|htm|html)+$/i)?"main":"general";return{title:h,targetPaths:i.slice(0,9),fullPath:i[0],queryStr:c,domainName:e.location.hostname,sp:d}};n=new i})(window,document)
# </script>
# <script type="text/javascript">
# if (typeof amznads !== "undefined") {
# 	var key = 'amznslots';
# 	var values = amznads.getTokens(); //comma separated
# }
# </script>
# <script type="text/javascript">
# window.dfpTargetingObject = {"cst_section":["sports","homepage"],"kw":["NBA","basketball"],"category":["NBA","basketball"],"cst_topic":["NBA","basketball"],"referrer":"","cst_subsection":["NBA","basketball"],"isMobile":"0"};
# 	dfpTargetingObject.level2adunit = "SMG_HoopsHype";
# 	googletag_cmd_push(function() {
# window.lawrence_dfp_desktop_skin = googletag.defineSlot("/7103/SMG_HoopsHype/skin/Sports/basketball/NBA.main", [1,1], "acm-ad-tag-lawrence_dfp_desktop_skin").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',["NBA","basketball"]).setTargeting('category',["NBA","basketball"]).setTargeting('cst_topic',["NBA","basketball"]).setTargeting('cst_subsection',["NBA","basketball"]).setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["skin"]);window.lawrence_dfp_desktop_interstitial = googletag.defineSlot("/7103/SMG_HoopsHype/interstitial/Sports/basketball/NBA.main", [[2,1]], "acm-ad-tag-lawrence_dfp_desktop_interstitial").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',["NBA","basketball"]).setTargeting('category',["NBA","basketball"]).setTargeting('cst_topic',["NBA","basketball"]).setTargeting('cst_subsection',["NBA","basketball"]).setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["interstitial"]);window.lawrence_dfp_desktop_sponsor_by_logo = googletag.defineSlot("/7103/SMG_HoopsHype/logo/Sports/basketball/NBA.main", [[100,50]], "acm-ad-tag-lawrence_dfp_desktop_sponsor_by_logo").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',["NBA","basketball"]).setTargeting('category',["NBA","basketball"]).setTargeting('cst_topic',["NBA","basketball"]).setTargeting('cst_subsection',["NBA","basketball"]).setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["logo"]);window.lawrence_dfp_desktop_top = googletag.defineSlot("/7103/SMG_HoopsHype/728x90_flex/Sports/basketball/NBA.main", ['fluid',[728,90],[970,66],[970,250]], "acm-ad-tag-lawrence_dfp_desktop_top").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',["NBA","basketball"]).setTargeting('category',["NBA","basketball"]).setTargeting('cst_topic',["NBA","basketball"]).setTargeting('cst_subsection',["NBA","basketball"]).setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["728x90_flex"]).setTargeting("nsf", ["paramount", "paramount-16_9"]);window.lawrence_dfp_desktop_top_300x250 = googletag.defineSlot("/7103/SMG_HoopsHype/300x250_1a/Sports/basketball/NBA.main", [[300,250],[300,600]], "acm-ad-tag-lawrence_dfp_desktop_top_300x250").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',["NBA","basketball"]).setTargeting('category',["NBA","basketball"]).setTargeting('cst_topic',["NBA","basketball"]).setTargeting('cst_subsection',["NBA","basketball"]).setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["300x250_1a"]);window.lawrence_dfp_desktop_bottom_300x250 = googletag.defineSlot("/7103/SMG_HoopsHype/300x250_2a/Sports/basketball/NBA.main", [[300,250],[300,600]], "acm-ad-tag-lawrence_dfp_desktop_bottom_300x250").addService(googletag.pubads().setTargeting('cst_section',["sports","homepage"]). ...
# if ( ! window.hasOwnProperty( 'wasabiAsyncStickCallback' ) ) {
# 	window.wasabiAsyncStickCallback = function() {
# 		'use strict';
# 		window.wasabiAsyncStickAd = true;
# 	};
# }
# if ( null !== localStorage.getItem( 'kxgannett_kuid' ) ) {
# 	googletag.pubads().setTargeting( 'kxgannett_kuid', localStorage.getItem( 'kxgannett_kuid' ) );
# }
# googletag.pubads().setTargeting( 'topic', window.dfpTargetingObject.kw );
# googletag.pubads().enableSingleRequest();
# googletag.pubads().enableLazyLoad({"fetchMarginPercent": 100,"renderMarginPercent": 50,"mobileScaling": 2.0});
# if( 'undefined' !== typeof bidManager && bidManager ) {
# 	bidManager.initialize();
# }
# googletag.enableServices();
#
# });
# </script>
# <link href="https://s2.wp.com/?custom-css=1&amp;csblog=5O7Gu&amp;cscache=6&amp;csrev=56" id="custom-css-css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 		var is_user_logged_in = 0;
# 	</script>
# </head>
# <body class="customizer-styles-applied highlander-enabled highlander-light salaries page-template-default infinite-scroll neverending">
# <div id="acm-ad-tag-lawrence_dfp_desktop_skin" style="width:1px; height:1px;"><script type="text/javascript">googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-lawrence_dfp_desktop_skin'); });</script></div><div id="acm-ad-tag-lawrence_dfp_desktop_interstitial" style="width:%width%px; height:%height%px;"><script type="text/javascript">googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-lawrence_dfp_desktop_interstitial'); });</script></div><div id="acm-ad-tag-" style="width:%width%px; height:%height%px;"><script type="text/javascript">googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-'); });</script></div>
# <div id="wrapper">
# <div class="sticky-header-ad-above-nav-extra-space"></div>
# <div class="header-ad--above-nav sticky-header-ad-above-nav" id="header-ad">
# <div id="acm-ad-tag-lawrence_dfp_desktop_top" style="width:%width%px; height:%height%px;"><script type="text/javascript">googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-lawrence_dfp_desktop_top'); });</script></div></div>
# <div class="sticky-header-ad-below-nav-extra-space"></div>
# <div class="wrapper-holder">
# <div class="widget newsletter-modal newsletter-modal--hidden widget--newsletter widget--box" id="usat-newsletter-modal">
# <div class="newsletter__wrapper modal" style="display: none;">
# <div class="newsletter__signup-wrapper">
# <div class="newsletter__logo">
# <img src="https://usathoopshype.files.wordpress.com/2017/01/logo-hoopshype-header.png"/>
# </div>
# <form action="https://hoopshype.com/wp-json/usat/v1/gems/subscribe/" class="newsletter_form" novalidate="novalidate">
# <label class="newsletter__input-label" for="newsletter-email-input">
# <span class="screen-reader-text">Email</span>
# <input class="newsletter__input" id="newsletter-email-input" name="email" placeholder="you@domain.com" required="" type="email"/>
# <span aria-hidden="true" class="newsletter__input-icon"></span>
# </label>
# <button class="newsletter__button" type="submit">Sign up			</button>
# <div class="newsletter-close-alt">
# <a class="newsletter__close-button" href="javascript:void(0);">No, thanks</a>
# </div>
# </form>
# <div class="newsletter__sidetext">
# <h3>Are you in?</h3>
# <p>Sign up for the HoopsHype daily email newsletter for the top stories every day.</p>
# </div>
# <div class="newsletter__state newsletter__state--error">
# <h3 class="newsletter__header newsletter__header--error">An error has occured</h3>
# <p class="newsletter__text newsletter__text--error">
# 				Please re-enter your email address.			</p>
# </div>
# </div>
# <div class="newsletter__state newsletter__state--success">
# <h3 class="newsletter__header">Thanks for signing up!</h3>
# <p class="newsletter__text">
# 			You'll now receive the top HoopsHype stories each day directly in your inbox.		</p>
# <div class="newsletter-close-alt">
# <a class="newsletter__close-button" href="javascript:void(0);">Close</a>
# </div>
# </div>
# <div class="newsletter-phone-wrapper">
# <div class="daily-newsletter-phone-wrapper">
# <img alt="newsletter" class="daily-newsletter-phone-image" src="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/modules/newsletter/images/phone.png"/>
# <div class="daily-newsletter-phone-wrapper-viewport">
# <div class="daily-newsletter__site-logo">
# <img class="daily-newsletter-logo-img" src="https://usathoopshype.files.wordpress.com/2017/01/logo-hoopshype-header.png"/>
# </div>
# <div class="daily-newsletter__site-top-stories">
# <img alt="top-stories" src="https://s2.wp.com/wp-content/themes/vip/usatoday-lawrence/modules/newsletter/images/topstories.png"/>
# </div>
# <div class="daily-newsletter__latest-image">
# <img src="https://usathoopshype.files.wordpress.com/2020/05/pippen-phil-jackson-1995.jpg?w=272&amp;h=250&amp;crop=1"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="newsletter__close">
# <a class="newsletter__close-button" href="javascript:void(0);">×</a>
# </div>
# </div><div class="branding" id="nav-branding">
# <span class="branding__logos">
# <a class="branding__logo-link" href="https://hoopshype.com" title="HoopsHype">
# <img alt="HoopsHype" class="branding__logo" height="30" src="https://usathoopshype.files.wordpress.com/2017/01/logo-hoopshype-header.png"/>
# </a>
# </span>
# <span class="branding__search ui-front">
# <form action="https://hoopshype.com" class="branding__search-form" method="get" role="search">
# <input class="branding__search-input" name="s" placeholder="search HoopsHype" type="text" value=""/>
# <a class="branding__search-close"></a>
# </form>
# </span>
# <a class="branding__brand" href="http://usatodaysports.com" target="_blank" title="USA TODAY Sports">
# <img alt="USA Today Sports" class="branding__brand-image" height="24" src="https://usathoopshype.files.wordpress.com/2017/01/usat-logo-header.png"/>
# </a>
# <a class="branding__mobile"></a>
# </div>
# <header class="nav">
# <nav class="nav__wrap">
# <ul class="nav__menu">
# <li class="nav__item nav__item--rumors nav__item--parent sub-menu-3columns sub-menu-columns-offset200" id="menu-item-423204"><a href="/rumors/" title="NBA Rumors">Rumors</a>
# <ul class="sub-menu">
# <li class="nav__item nav__item--atlanta-hawks" id="menu-item-1023487"><a href="https://hoopshype.com/team/atlanta-hawks/" title="Atlanta Rumors">Atlanta Hawks</a></li>
# <li class="nav__item nav__item--boston-celtics" id="menu-item-1023488"><a href="https://hoopshype.com/team/boston-celtics/" title="Boston Rumors">Boston Celtics</a></li>
# <li class="nav__item nav__item--brooklyn-nets" id="menu-item-1023489"><a href="https://hoopshype.com/team/brooklyn-nets/" title="Brooklyn Rumors">Brooklyn Nets</a></li>
# <li class="nav__item nav__item--charlotte-hornets" id="menu-item-1023490"><a href="https://hoopshype.com/team/charlotte-hornets/" title="Charlotte Rumors">Charlotte Hornets</a></li>
# <li class="nav__item nav__item--chicago-bulls" id="menu-item-1023491"><a href="https://hoopshype.com/team/chicago-bulls/" title="Chicago Rumors">Chicago Bulls</a></li>
# <li class="nav__item nav__item--cleveland-cavaliers" id="menu-item-1023492"><a href="https://hoopshype.com/team/cleveland-cavaliers/" title="Cleveland Rumors">Cleveland Cavaliers</a></li>
# <li class="nav__item nav__item--dallas-mavericks" id="menu-item-1023493"><a href="https://hoopshype.com/team/dallas-mavericks/" title="Dallas Rumors">Dallas Mavericks</a></li>
# <li class="nav__item nav__item--denver-nuggets" id="menu-item-1023494"><a href="https://hoopshype.com/team/denver-nuggets/" title="Denver Rumors">Denver Nuggets</a></li>
# <li class="nav__item nav__item--detroit-pistons" id="menu-item-1023495"><a href="https://hoopshype.com/team/detroit-pistons/" title="Detroit Rumors">Detroit Pistons</a></li>
# <li class="nav__item nav__item--golden-state-warriors" id="menu-item-1023496"><a href="https://hoopshype.com/team/golden-state-warriors/" title="Golden State Rumors">Golden State Warriors</a></li>
# <li class="nav__item nav__item--houston-rockets" id="menu-item-1023497"><a href="https://hoopshype.com/team/houston-rockets/" title="Houston Rumors">Houston Rockets</a></li>
# <li class="nav__item nav__item--indiana-pacers" id="menu-item-1023498"><a href="https://hoopshype.com/team/indiana-pacers/" title="Indiana Rumors">Indiana Pacers</a></li>
# <li class="nav__item nav__item--los-angeles-clippers" id="menu-item-1023499"><a href="https://hoopshype.com/team/los-angeles-clippers/" title="LA Clippers Rumors">Los Angeles Clippers</a></li>
# <li class="nav__item nav__item--los-angeles-lakers" id="menu-item-1023500"><a href="https://hoopshype.com/team/los-angeles-lakers/" title="LA Lakers Rumors">Los Angeles Lakers</a></li>
# <li class="nav__item nav__item--memphis-grizzlies" id="menu-item-1023501"><a href="https://hoopshype.com/team/memphis-grizzlies/" title="Memphis Rumors">Memphis Grizzlies</a></li>
# <li class="nav__item nav__item--miami-heat" id="menu-item-1023502"><a href="https://hoopshype.com/team/miami-heat/" title="Miami Rumors">Miami Heat</a></li>
# <li class="nav__item nav__item--milwaukee-bucks" id="menu-item-1023503"><a href="https://hoopshype.com/team/milwaukee-bucks/" title="Milwaukee Rumors">Milwaukee Bucks</a></li>
# <li class="nav__item nav__item--minnesota-timberwolves" id="menu-item-1023504"><a href="https://hoopshype.com/team/minnesota-timberwolves/" title="Minnesota Rumors">Minnesota Timberwolves</a></li>
# <li class="nav__item nav__item--new-orleans-pelicans" id="menu-item-1023505"><a href="https://hoopshype.com/team/new-orleans-pelicans/" title="New Orleans Rumors">New Orleans Pelicans</a></li>
# <li class="nav__item nav__item--new-york-knicks" id="menu-item-1023506"><a href="https://hoopshype.com/team/new-york-knicks/" title="New York Rumors">New York Knicks</a></li>
# <li class="nav__item nav__item--oklahoma-city-thunder" id="menu-item-1023507"><a href="https://hoopshype.com/team/oklahoma-city-thunder/" title="Oklahoma City Rumors">Oklahoma City Thunder</a></li>
# <li class="nav__item nav__item--orlando-magic" id="menu-item-1023508"><a href="https://hoopshype.com/team/orlando-magic/" title="Orlando Rumors">Orlando Magic</a></li>
# <li class="nav__item nav__item--philadelphia-76ers" id="menu-item-1023509"><a href="https://hoopshype.com/team/philadelphia-76ers/" title="Philadelphia Rumors">Philadelphia 76ers</a></li>
# <li class="nav__item nav__item--phoenix-suns" id="menu-item-1023510"><a href="https://hoopshype.com/team/phoenix-suns/" title="Phoenix Rumors">Phoenix Suns</a></li>
# <li class="nav__item nav__item--portland-trail-blazers" id="menu-item-1023511"><a href="https://hoopshype.com/team/portland-trail-blazers/" title="Portland Rumors">Portland Trail Blazers</a></li>
# <li class="nav__item nav__item--sacramento-kings" id="menu-item-1023512"><a href="https://hoopshype.com/team/sacramento-kings/" title="Sacramento Rumors">Sacramento Kings</a></li>
# <li class="nav__item nav__item--san-antonio-spurs" id="menu-item-1023513"><a href="https://hoopshype.com/team/san-antonio-spurs/" title="San Antonio Rumors">San Antonio Spurs</a></li>
# <li class="nav__item nav__item--toronto-raptors" id="menu-item-1023514"><a href="https://hoopshype.com/team/toronto-raptors/" title="Toronto Rumors">Toronto Raptors</a></li>
# <li class="nav__item nav__item--utah-jazz" id="menu-item-1023515"><a href="https://hoopshype.com/team/utah-jazz/" title="Utah Rumors">Utah Jazz</a></li>
# <li class="nav__item nav__item--washington-wizards" id="menu-item-1023516"><a href="https://hoopshype.com/team/washington-wizards/" title="Washington Rumors">Washington Wizards</a></li>
# </ul>
# </li>
# <li class="nav__item nav__item--salaries nav__item--parent sub-menu-minwidth140" id="menu-item-458969"><a href="/salaries/" title="NBA Salaries">Salaries</a>
# <ul class="sub-menu">
# <li class="nav__item nav__item--current nav__item--players" id="menu-item-16"><a aria-current="page" href="https://hoopshype.com/salaries/players/" title="NBA Player Salaries">Players</a></li>
# <li class="nav__item nav__item--teams" id="menu-item-12"><a href="https://hoopshype.com/salaries/" title="NBA Salaries">Teams</a></li>
# <li class="nav__item nav__item--salary-cap" id="menu-item-1328720"><a href="https://hoopshype.com/2020/03/16/los-angeles-lakers-their-salary-cap-situation-right-now/">Salary cap</a></li>
# <li class="nav__item nav__item--history" id="menu-item-1278372"><a href="https://hoopshype.com/salaries/2000-2001/">History</a></li>
# </ul>
# </li>
# <li class="nav__item nav__item--twitter nav__item--parent sub-menu-minwidth140" id="menu-item-1022515"><a href="/social/" title="NBA Media Twitters">Twitter</a>
# <ul class="sub-menu">
# <li class="nav__item nav__item--media" id="menu-item-18"><a href="/social/" title="NBA Media Twitters">Media</a></li>
# <li class="nav__item nav__item--players" id="menu-item-999057"><a href="/social/tweets/" title="NBA Players on Twitter">Players</a></li>
# </ul>
# </li>
# <li class="nav__item nav__item--features nav__item--parent sub-menu-3columns sub-menu-columns-offset200" id="menu-item-423198"><a href="#">Features</a>
# <ul class="sub-menu">
# <li class="nav__item nav__item--agents" id="menu-item-1000630"><a href="/reps/" title="NBA Agents">Agents</a></li>
# <li class="nav__item nav__item--awards" id="menu-item-1278971"><a href="https://hoopshype.com/2019/08/08/nba-awards-all-the-winners-in-league-history/">Awards</a></li>
# <li class="nav__item nav__item--birthdays" id="menu-item-1231160"><a href="https://hoopshype.com/2019/01/13/which-nba-player-was-born-the-same-day-as-you-find-out-here/">Birthdays</a></li>
# <li class="nav__item nav__item--birthplaces" id="menu-item-1006555"><a href="/2019/08/20/nba-players-birthplaces/" title="Birthplaces">Birthplaces</a></li>
# <li class="nav__item nav__item--depth-charts" id="menu-item-1271888"><a href="https://hoopshype.com/2019/07/10/nba-depth-charts/">Depth Charts</a></li>
# <li class="nav__item nav__item--draft" id="menu-item-11"><a href="/2018/01/09/nba-mock-draft-2018/" title="NBA Draft">Draft</a></li>
# <li class="nav__item nav__item--free-agency-2019" id="menu-item-17"><a href="/2018/08/09/nba-free-agency-2019-the-top-players" title="NBA Free Agency 2019">Free Agency 2019</a></li>
# <li class="nav__item nav__item--free-agency-2020" id="menu-item-1118240"><a href="https://hoopshype.com/2019/07/18/nba-free-agency-2020-the-top-players/">Free Agency 2020</a></li>
# <li class="nav__item nav__item--hoopshype-explains" id="menu-item-1207357"><a href="https://hoopshype.com/category/hoopshype-explains/">HoopsHype Explains</a></li>
# <li class="nav__item nav__item--hoopshype-podcasts" id="menu-item-1000631"><a href="/category/podcast/">HoopsHype Podcasts</a></li>
# <li class="nav__item nav__item--instagram" id="menu-item-1006554"><a href="/social/gallery/" title="NBA Players on Instagram">Instagram</a></li>
# <li class="nav__item nav__item--key-contract-dates" id="menu-item-1265345"><a href="https://hoopshype.com/2019/06/17/nba-contracts-key-dates-deadlines-options-trade-eligibility/">Key Contract Dates</a></li>
# <li class="nav__item nav__item--longform" id="menu-item-1000632"><a href="https://hoopshype.com/category/longform/" title="Longform">Longform</a></li>
# <li class="nav__item nav__item--nba-2k-ratings" id="menu-item-1278805"><a href="https://hoopshype.com/nba2k/">NBA 2K Ratings</a></li>
# <li class="nav__item nav__item--nicknames" id="menu-item-1241341"><a href="https://hoopshype.com/2019/02/24/all-the-nicknames-in-nba-history/">Nicknames</a></li>
# <li class="nav__item nav__item--players" id="menu-item-423200"><a href="/players/" title="NBA Players">Players</a></li>
# <li class="nav__item nav__item--re-drafts" id="menu-item-1119544"><a href="https://hoopshype.com/tag/re-drafts/">Re-Drafts</a></li>
# <li class="nav__item nav__item--roster-details" id="menu-item-1296517"><a href="https://hoopshype.com/2019/11/07/all-nba-rosters-in-one-page-with-some-extra-details/">Roster Details</a></li>
# <li class="nav__item nav__item--top-rumors" id="menu-item-1160065"><a href="https://hoopshype.com/category/top-rumors/">Top Rumors</a></li>
# <li class="nav__item nav__item--transactions" id="menu-item-10"><a href="/transactions.htm" title="NBA Transactions">Transactions</a></li>
# </ul>
# </li>
# </ul>
# <ul class="nav__social">
# <li class="nav__item nav__item--social nav__item--facebook">
# <a class="nav__item-link" href="http://facebook.com/hoopshype"></a>
# </li>
# <li class="nav__item nav__item--social nav__item--twitter">
# <a class="nav__item-link" href="https://twitter.com/hoopshype"></a>
# </li>
# <li class="nav__item nav__item--social nav__item--podcast">
# <a class="nav__item-link" href="https://hoopshype.com/category/podcast/"></a>
# </li>
# </ul>
# </nav>
# </header>
# <div class="site-main" id="main">
# <div class="content-area" id="primary">
# <div class="site-content" id="content" role="main">
# <header class="entry-header page">
# <div id="headline">
# <h1 class="entry-title">NBA Player Salaries</h1>
# </div>
# </header>
# <div class="container divider" id="content-container">
# <div class="entry-content">
# <div class="story-share-buttons no-share-count sms">
# <div class="share-button share-count">
# <span class="icomoon icon-shares"></span>
# <span class="count">0</span> <span class="share-text"> share </span>
# </div>
# <div class="share-button share-facebook st-custom-button" data-network="facebook" data-short-url="" data-track="hoopshypestoryfb" data-url="https://hoopshype.com/salaries/players/" id="share-facebook">
# <span class="icomoon icon-facebook"></span>
# <span class="share-text">share</span>
# </div>
# <div class="share-button share-twitter st-custom-button" data-network="twitter" data-short-url="" data-track="hoopshypestorytwitter" data-url="https://hoopshype.com/salaries/players/" data-username="hoopshype" id="share-twitter">
# <span class="icomoon icon-twitter"></span>
# <span class="share-text">tweet</span>
# </div>
# <div class="share-button share-pinterest st-custom-button" data-network="pinterest" data-short-url="" data-track="hoopshypestorypinterest" data-url="https://hoopshype.com/salaries/players/" id="share-pinterest">
# <span class="icomoon icon-pinterest"></span>
# <span class="share-text">pin</span>
# </div>
# <div class="share-button share-sms st-custom-button" data-network="sms" data-short-url="" data-track="hoopshypestorysms" data-url="https://hoopshype.com/salaries/players/" id="share-sms">
# <span class="icomoon icon-sms"></span>
# <span class="share-text">sms</span>
# </div>
# <div class="share-button share-whatsapp st-custom-button" data-network="whatsapp" data-short-url="" data-track="hoopshypestorywhatsapp" data-url="https://hoopshype.com/salaries/players/" id="share-whatsapp">
# <span class="icomoon icon-whatsapp"></span>
# <span class="share-text">send</span>
# </div>
# <div class="share-button share-email st-custom-button" data-message="" data-network="email" data-short-url="" data-track="hoopshypestoryemail" data-url="https://hoopshype.com/salaries/players/" id="share-email">
# <span class="icomoon icon-email"></span>
# <span class="share-text">email</span>
# </div>
# </div>
# <div class="st_buttons_for_api">
# <span class="st_facebook_hcount" displaytext="Facebook"></span>
# <span class="st_twitter_hcount" displaytext="Tweet"></span>
# <span class="st_email_hcount" displaytext="Email"></span>
# </div>
# <div class="hoopshype-salaries-wrap tabs tabs-noinit hoopshype-salaries-players">
# <ul class="tab-controls ui-tabs-nav" data-selectedclass="ui-tabs-active">
# <li class="">
# <a href="https://hoopshype.com/salaries/">Team Payrolls</a>
# </li>
# <li class="ui-tabs-active">
# <a href="https://hoopshype.com/salaries/players/">Player Salaries</a>
# </li>
# </ul>
# <div class="salaries-team-selector-top">
# <ul class="social-tabs team-list">
# <li class="all">
# <a class="active-team" href="https://hoopshype.com/salaries/players/">
# 			2019/20		</a>
# <ul class="team-list-ul">
# <li class="allteams">
# <a href="https://hoopshype.com/salaries/players/">
# 					2019/20				</a>
# </li>
# <li class="group">
# <ul>
# <li>
# <a href="https://hoopshype.com/salaries/players/2018-2019/">
# 									2018/19								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2016-2017/">
# 									2016/17								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2014-2015/">
# 									2014/15								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2012-2013/">
# 									2012/13								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2010-2011/">
# 									2010/11								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2008-2009/">
# 									2008/09								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2006-2007/">
# 									2006/07								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2004-2005/">
# 									2004/05								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2002-2003/">
# 									2002/03								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2000-2001/">
# 									2000/01								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1998-1999/">
# 									1998/99								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1996-1997/">
# 									1996/97								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1994-1995/">
# 									1994/95								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1992-1993/">
# 									1992/93								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1990-1991/">
# 									1990/91								</a>
# </li>
# </ul>
# </li>
# <li class="group">
# <ul>
# <li>
# <a href="https://hoopshype.com/salaries/players/2017-2018/">
# 									2017/18								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2015-2016/">
# 									2015/16								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2013-2014/">
# 									2013/14								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2011-2012/">
# 									2011/12								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2009-2010/">
# 									2009/10								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2007-2008/">
# 									2007/08								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2005-2006/">
# 									2005/06								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2003-2004/">
# 									2003/04								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/2001-2002/">
# 									2001/02								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1999-2000/">
# 									1999/00								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1997-1998/">
# 									1997/98								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1995-1996/">
# 									1995/96								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1993-1994/">
# 									1993/94								</a>
# </li>
# <li>
# <a href="https://hoopshype.com/salaries/players/1991-1992/">
# ...
# <li class="mobile-nav__item mobile-nav__item--top-rumors"><a href="https://hoopshype.com/category/top-rumors/">Top Rumors</a></li>
# <li class="mobile-nav__item mobile-nav__item--transactions"><a href="/transactions.htm" title="NBA Transactions">Transactions</a></li>
# </ul>
# </li>
# </ul>
# <ul class="mobile-nav__footer-menu">
# <li class="mobile-nav__item mobile-nav__item--terms-of-service" id="menu-item-1179960"><a href="https://cm.usatoday.com/terms">Terms of Service</a></li>
# <li class="mobile-nav__item mobile-nav__item--privacy-policy" id="menu-item-1304766"><a href="https://cm.usatoday.com/privacy">Privacy Policy</a></li>
# <li class="mobile-nav__item mobile-nav__item--your-california-privacy-rights-privacy-policy" id="menu-item-1179959"><a href="https://cm.usatoday.com/privacy-policy">Your California Privacy Rights/Privacy Policy</a></li>
# <li class="mobile-nav__item mobile-nav__item--do-no-sell-my-info-cookie-policy" id="menu-item-1179961"><a href="https://cm.usatoday.com/cookies">Do No Sell My Info/Cookie Policy</a></li>
# <li class="mobile-nav__item mobile-nav__item--vipcom">
# 				Powered by <a class="powered-by-wpcom" href="https://wpvip.com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=hoopshype.com" rel="generator nofollow">WordPress.com VIP</a> </li>
# </ul>
# </div>
# <div id="main_ad" style="height:1px; width:1px; overflow:auto;position: absolute;left: -999em;"><!--AD UNIT 4--></div><script src="//0.gravatar.com/js/gprofiles.js?ver=202020y"></script>
# <script>
# var WPGroHo = {"my_hash":""};
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781h" type="text/javascript"></script>
# <script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
# <div style="display:none">
# </div>
# <div id="carousel-reblog-box">
# <form action="#" name="carousel-reblog">
# <textarea id="carousel-reblog-content" name="carousel-reblog-content" placeholder="Add your thoughts here... (optional)"></textarea>
# <label for="carousel-reblog-to-blog-id" id="carousel-reblog-lblogid">Post to</label>
# <select id="carousel-reblog-to-blog-id" name="carousel-reblog-to-blog-id">
# </select>
# <div class="submit">
# <span class="canceltext"><a class="cancel" href="#">Cancel</a></span>
# <input class="button" id="carousel-reblog-submit" name="carousel-reblog-submit" type="submit" value="Reblog Post"/>
# <input id="carousel-reblog-blog-id" type="hidden" value="85827622"/>
# <input id="carousel-reblog-blog-url" type="hidden" value="https://hoopshype.com"/>
# <input id="carousel-reblog-blog-title" type="hidden" value="HoopsHype"/>
# <input id="carousel-reblog-post-url" type="hidden" value=""/>
# <input id="carousel-reblog-post-title" type="hidden" value=""/>
# </div>
# <input id="_wpnonce" name="_wpnonce" type="hidden" value="0999f4808b"/><input name="_wp_http_referer" type="hidden" value="/salaries/players/"/> </form>
# <div class="arrow"></div>
# </div>
# <link href="https://s2.wp.com/_static/??-eJx9i0sOwjAMBS9EsKqqkVggzhJcKzh1nShOBNyesgCJBd3N+wzci2NF6TMZJIN2Y1yu+fGFI5odYHth1kbaYO2uSI+sBpGUKm/DH9xzMdTcjQQStRJwcZ9iT2osNLsYRKg+f9Nbu6znYfLj6Ad/mtIL8rNR8A==?cssminify=yes" id="all-css-0-2" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://s0.wp.com/_static/??/wp-content/js/devicepx.js,/wp-content/mu-plugins/infinity/infinity.js?m=1585329779j" type="text/javascript"></script>
# <script src="https://native.sharethrough.com/assets/sfp.js?ver=1"></script>
# <script>
# var uiAutocompleteL10n = {"noResults":"No results found.","oneResult":"1 result found. Use up and down arrow keys to navigate.","manyResults":"%d results found. Use up and down arrow keys to navigate.","itemSelected":"Item selected."};
# </script>
# <script>
# var thickboxL10n = {"next":"Next >","prev":"< Prev","image":"Image","of":"of","close":"Close","noiframes":"This feature requires inline frames. You have iframes disabled or your browser does not support them.","loadingAnimation":"https:\/\/s2.wp.com\/wp-includes\/js\/thickbox\/loadingAnimation.gif"};
# </script>
# <script>
# var newsletter = {"i18n":{"cancel":"Cancel","close":"Close","want_more":"Want More?","try_again":"Please try again"},"force_modal":"","force_abovenav":"","is_mobile":"","modal_enabled":"","abovenav_enabled":"","cookie_expiry":"30","inline_position":"10","confirm_url":"","wiresites":{"enabled":false,"url":"https:\/\/hoopshype.com\/daily-email-newsletter"}};
# </script>
# <script>
# var _LAWRENCE_ADS_EXPORTS = {"ad_refresh":{"seconds":"30","refresh_type":"all","distance":"2000","active":"1"}};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# ( 'fetch' in window ) || document.write( '<script src="https://s0.wp.com/wp-includes/js/dist/vendor/wp-polyfill-fetch.min.js?m=1573572739h&#038;ver=3.0.0"></scr' + 'ipt>' );( document.contains ) || document.write( '<script src="https://s1.wp.com/wp-includes/js/dist/vendor/wp-polyfill-node-contains.min.js?m=1540208548h&#038;ver=3.42.0"></scr' + 'ipt>' );( window.DOMRect ) || document.write( '<script src="https://s0.wp.com/wp-includes/js/dist/vendor/wp-polyfill-dom-rect.min.js?m=1585663916h&#038;ver=3.42.0"></scr' + 'ipt>' );( window.URL && window.URL.prototype && window.URLSearchParams ) || document.write( '<script src="https://s2.wp.com/wp-includes/js/dist/vendor/wp-polyfill-url.min.js?m=1585663916h&#038;ver=3.6.4"></scr' + 'ipt>' );( window.FormData && window.FormData.prototype.keys ) || document.write( '<script src="https://s1.wp.com/wp-includes/js/dist/vendor/wp-polyfill-formdata.min.js?m=1550600082h&#038;ver=3.0.12"></scr' + 'ipt>' );( Element.prototype.matches && Element.prototype.closest ) || document.write( '<script src="https://s2.wp.com/wp-includes/js/dist/vendor/wp-polyfill-element-closest.min.js?m=1540208548h&#038;ver=2.0.2"></scr' + 'ipt>' );
# </script>
# <script src="https://www.googletagservices.com/tag/js/gpt.js?ver=1.0"></script>
# <script>
# var wpcomVipAnalytics = {"is_404":"0","is_home":"1","is_single":"0","is_front_page":"1","is_archive":"0","percentToTrack":"1"};
# </script>
# <script src="https://s2.wp.com/_static/??-eJytz8sKg0AMBdAfakwfjNBF6bekTqgj88JE7fTrqy5st0JXF8LNgYtThiZF5agYBsh+eLooeIbRZewE5wCK5Iu6RqpODvjzoC0HXjs4CGmyVDbB07uAT2SBX3PZsl247VoFF//J7aDalLK0JfMi9Cw5RXEjg9LD866NX4lEWGUBhTz1bnXu4XYydX29GFMfuw8UjIgb" type="text/javascript"></script>
# <script>
# var OneSignalOptions = {"appId":"a8d17feb-85d9-47a3-bb52-ead9529a0b4c"};
# </script>
# <script async="async" src="//cdn.onesignal.com/sdks/OneSignalSDK.js?ver=5.0" type="text/javascript"></script>
# <script type="text/javascript">
# 					var OneSignal = window.OneSignal || [];
# 					setTimeout(
# 						function() {
# 							OneSignal.push(function() {
# 								OneSignal.init({"appId":"a8d17feb-85d9-47a3-bb52-ead9529a0b4c"})
# 							});
# 						},
# 						10000
# 					);
# 				</script>
# <script>
# var wasabiAdFollowOptions = {"headerAdPosition":"0","enable":"","headerHeight":"60","stickyAdSettings":"{\"66\":{\"follow\":\"0\",\"minWidth\":\"1024\",\"stickTime\":\"4\"},\"90\":{\"follow\":\"0\",\"minWidth\":\"1024\",\"stickTime\":\"4\"},\"250\":{\"follow\":\"0\",\"minWidth\":\"1024\",\"stickTime\":\"4\"}}"};
# </script>
# <script>
# var jetpackCarouselStrings = {"widths":[370,700,1000,1200,1400,2000],"is_logged_in":"","lang":"en","ajaxurl":"https:\/\/hoopshype.com\/wp-admin\/admin-ajax.php","nonce":"757c7cfaf3","display_exif":"1","display_geo":"1","single_image_gallery":"1","single_image_gallery_media_file":"","background_color":"black","comment":"Comment","post_comment":"Post Comment","write_comment":"Write a Comment...","loading_comments":"Loading Comments...","download_original":"View full size <span class=\"photo-size\">{0}<span class=\"photo-size-times\">\u00d7<\/span>{1}<\/span>","no_comment_text":"Please be sure to submit some text with your comment.","no_comment_email":"Please provide an email address to comment.","no_comment_author":"Please provide your name to comment.","comment_post_error":"Sorry, but there was an error posting your comment. Please try again later.","comment_approved":"Your comment was approved.","comment_unapproved":"Your comment is in moderation.","camera":"Camera","aperture":"Aperture","shutter_speed":"Shutter Speed","focal_length":"Focal Length","copyright":"Copyright","comment_registration":"0","require_name_email":"1","login_url":"https:\/\/usathoopshype.wordpress.com\/wp-login.php?redirect_to=https%3A%2F%2Fhoopshype.com%2F2020%2F05%2F12%2Flebron-james-the-case-for-greatest-of-all-time-goat-status%2F","blog_id":"85827622","meta_data":["camera","aperture","shutter_speed","focal_length","copyright"],"local_comments_commenting_as":"<fieldset><label for=\"email\">Email (Required)<\/label> <input type=\"text\" name=\"email\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-email-field\" \/><\/fieldset><fieldset><label for=\"author\">Name (Required)<\/label> <input type=\"text\" name=\"author\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-author-field\" \/><\/fieldset><fieldset><label for=\"url\">Website<\/label> <input type=\"text\" name=\"url\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-url-field\" \/><\/fieldset>","reblog":"Reblog","reblogged":"Reblogged","reblog_add_thoughts":"Add your thoughts here... (optional)","reblogging":"Reblogging...","post_reblog":"Post Reblog","stats_query_args":"blog=85827622&v=wpcom&tz=-4&user_id=0&subd=usathoopshype","is_public":"1","reblog_enabled":""};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script src="https://platform-api.sharethis.com/js/sharethis.js#product=sop-wordpress-plugin"></script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script><script type="text/javascript">
# 			jQuery.extend( infiniteScroll.settings.scripts, ["jquery-core","jquery-migrate","jquery","postmessage","mobile-useragent-info","amazon-adsystem","lawrence-header-bidding","lawrence-ads-ias","lawrence-tealium","lawrence-brightcove-tealium-integration","lawrence-ad-marketplace-sponsored-search-results-js","lawrence-confiant","lawrence-gallery-tealium-extensions","usatoday-gallery","lawrence-skip-link-focus-fix","lawrence-jquery-plugins","lawrence-jquery-sticky","lawrence-jquery-sidr","adrizer","spin","jquery.spin","swfobject","videopress","grofiles-cards","wpgroho","devicepx","the-neverending-homepage","sharethrough-native-responsive","lawrence-paramount-script","lawrence-native-gravity-script","jquery-ui-core","jquery-ui-widget","jquery-ui-position","jquery-ui-menu","wp-polyfill","wp-dom-ready","wp-a11y","jquery-ui-autocomplete","usatoday-flip","usatoday-rumors","jquery-ui-mouse","jquery-ui-resizable","jquery-ui-draggable","jquery-ui-button","jquery-ui-dialog","usat-cookie","thickbox","wasabi-newsletter-widget","lawrence-main","lawrence-ads-js","lawrence-confiant-js","wpcom-vip-analytics","lawrence-lazy-load-images","lawrence-lazy-load-images-custom","hoopshype-responsive-tables","hoopshype-salaries","onesignal-sdk","underscore","hoopshype-nav","hoopshype-mobile-nav","wasabi-utils","wasabi-navigation","wasabi-sidebar","wasabi-main","wpcom-masterbar-js","wpcom-masterbar-tracks-js","jetpack-carousel","tiled-gallery","sop-script"] );
# 			jQuery.extend( infiniteScroll.settings.styles, ["wpcom-smileys","the-neverending-homepage","wp-block-library","wpcom-core-compat-playlist-styles","wpcom-text-widget-styles","wpcom-bbpress2-staff-css","video-galleries","dashicons","wp-jquery-ui-dialog","lawrence-child-wasabi","lawrence-child-hoopshype","jetpack_social_media_icons_widget","geo-location-flair","reblogging","h4-global","galleria-theme","google-fonts-ubuntu","thickbox","genericons","jetpack-carousel","tiled-gallery"] );
# 		</script><script async="" defer="" src="//stats.wp.com/w.js?61" type="text/javascript"></script>
# <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'85827622','blog_tz':'-4','user_lang':'en','blog_lang':'en','user_id':'0'}]);
# _stq.push(['view', {'blog':'85827622','v':'wpcom','tz':'-4','user_id':'0','subd':'usathoopshype'}]);
# function st_vt() {var x=document.createElement("img");x.src="https://pixel.wp.com/g.gif?blog=85827622&v=wpcomvt&tz=-4&user_id=0&subd=usathoopshype&rand="+Math.random();}
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '85827622', '0' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:0px;width:0px;overflow:hidden"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script></body>
# </html>
# <!--
# $$\
# $$ |
# $$ |      $$$$$$\  $$\  $$\  $$\  $$$$$$\   $$$$$$\  $$$$$$$\   $$$$$$$\  $$$$$$\
# $$ |      \____$$\ $$ | $$ | $$ |$$  __$$\ $$  __$$\ $$  __$$\ $$  _____|$$  __$$\
# $$ |      $$$$$$$ |$$ | $$ | $$ |$$ |  \__|$$$$$$$$ |$$ |  $$ |$$ /      $$$$$$$$ |
# $$ |     $$  __$$ |$$ | $$ | $$ |$$ |      $$   ____|$$ |  $$ |$$ |      $$   ____|
# $$$$$$$$\$$$$$$$ |\$$$$$\$$$$  |$$ |      \$$$$$$$\ $$ |  $$ |\$$$$$$$\ \$$$$$$$\
# \________|\_______| \_____\____/ \__|       \_______|\__|  \__| \_______| \_______|
#
# Brought to you by your good friends at USA Today Sports.
# -->

# %%
print(soup.title)
print(soup.title.text)
# Out:
# <title>NBA Player Salaries | HoopsHype</title>
# NBA Player Salaries | HoopsHype

# %%
salary2020 = []

all_td = soup.find_all('td')
for element in all_td:
    result = {}
    a_href = element.find('a')
    if a_href:
        result['name'] = a_href.text.strip()
        result['salary'] = element.find_next('td').attrs['data-value'] #this html tree navigation was key to acquiring the appropriate salary amount

    if len(result) == 2:
        salary2020.append(result)

# %%
salary2020
# Out:
# [{'name': 'Stephen Curry', 'salary': '40231758'},
#  {'name': 'Russell Westbrook', 'salary': '38506482'},
#  {'name': 'Chris Paul', 'salary': '38506482'},
#  {'name': 'James Harden', 'salary': '38199000'},
#  {'name': 'John Wall', 'salary': '38199000'},
#  {'name': 'LeBron James', 'salary': '37436858'},
#  {'name': 'Kevin Durant', 'salary': '37199000'},
#  {'name': 'Blake Griffin', 'salary': '34449964'},
#  {'name': 'Kyle Lowry', 'salary': '33296296'},
#  {'name': 'Paul George', 'salary': '33005556'},
#  {'name': 'Klay Thompson', 'salary': '32742000'},
#  {'name': 'Kemba Walker', 'salary': '32742000'},
#  {'name': 'Kawhi Leonard', 'salary': '32742000'},
#  {'name': 'Jimmy Butler', 'salary': '32742000'},
#  {'name': 'Tobias Harris', 'salary': '32742000'},
#  {'name': 'Gordon Hayward', 'salary': '32700690'},
#  {'name': 'Mike Conley', 'salary': '32511623'},
#  {'name': 'Kyrie Irving', 'salary': '31742000'},
#  {'name': 'Khris Middleton', 'salary': '30603448'},
#  {'name': 'Paul Millsap', 'salary': '30350000'},
#  {'name': 'Damian Lillard', 'salary': '29802321'},
#  {'name': 'Kevin Love', 'salary': '28942830'},
#  {'name': 'Al Horford', 'salary': '28000000'},
#  {'name': 'Nikola Vucevic', 'salary': '28000000'},
#  {'name': 'DeMar DeRozan', 'salary': '27739975'},
#  {'name': 'CJ McCollum', 'salary': '27556959'},
#  {'name': 'Nikola Jokic', 'salary': '27504630'},
#  {'name': 'Andrew Wiggins', 'salary': '27504630'},
#  {'name': 'Joel Embiid', 'salary': '27504630'},
#  {'name': 'Kristaps Porzingis', 'salary': '27285000'},
#  {'name': 'Karl-Anthony Towns', 'salary': '27285000'},
#  {'name': 'Devin Booker', 'salary': '27285000'},
#  {'name': "D'Angelo Russell", 'salary': '27285000'},
#  {'name': 'Otto Porter', 'salary': '27250576'},
#  {'name': 'Anthony Davis', 'salary': '27093019'},
#  {'name': 'Andre Drummond', 'salary': '27093018'},
#  {'name': 'Bradley Beal', 'salary': '27093018'},
#  {'name': 'Hassan Whiteside', 'salary': '27093018'},
#  {'name': 'Jrue Holiday', 'salary': '26131111'},
#  {'name': 'LaMarcus Aldridge', 'salary': '26000000'},
#  {'name': 'Giannis Antetokounmpo', 'salary': '25842697'},
#  {'name': 'Steven Adams', 'salary': '25842697'},
#  {'name': 'Marc Gasol', 'salary': '25595700'},
#  {'name': 'Nicolas Batum', 'salary': '25565217'},
#  {'name': 'Rudy Gobert', 'salary': '25258427'},
#  {'name': 'Chandler Parsons', 'salary': '25102512'},
#  {'name': 'Harrison Barnes', 'salary': '24147727'},
#  {'name': 'Serge Ibaka', 'salary': '23271604'},
#  {'name': 'Danilo Gallinari', 'salary': '22615559'},
#  {'name': 'Victor Oladipo', 'salary': '21000000'},
#  {'name': 'Tim Hardaway Jr', 'salary': '20025127'},
#  {'name': 'Malcolm Brogdon', 'salary': '20000000'},
#  {'name': 'Terry Rozier', 'salary': '19894737'},
#  {'name': 'Aaron Gordon', 'salary': '19863636'},
#  {'name': 'Zach LaVine', 'salary': '19500000'},
#  {'name': 'Kent Bazemore', 'salary': '19269663'},
#  {'name': 'Tyler Johnson', 'salary': '19245370'},
#  {'name': 'Goran Dragic', 'salary': '19217900'},
#  {'name': 'Jeff Teague', 'salary': '19000000'},
#  {'name': 'Evan Turner', 'salary': '18606556'},
#  {'name': 'Draymond Green', 'salary': '18539130'},
#  {'name': 'Tristan Thompson', 'salary': '18539130'},
#  {'name': 'Julius Randle', 'salary': '18000000'},
#  {'name': 'Myles Turner', 'salary': '18000000'},
#  {'name': 'Gary Harris', 'salary': '17839286'},
#  {'name': 'Allen Crabbe', 'salary': '17818456'},
#  {'name': 'Reggie Jackson', 'salary': '17799677'},
#  {'name': 'Derrick Favors', 'salary': '17650000'},
#  {'name': 'Andre Iguodala', 'salary': '17185185'},
#  {'name': 'Evan Fournier', 'salary': '17150000'},
#  {'name': 'Bojan Bogdanovic', 'salary': '17000000'},
#  {'name': 'Bismack Biyombo', 'salary': '17000000'},
#  {'name': 'Clint Capela', 'salary': '16896552'},
#  {'name': 'Gorgui Dieng', 'salary': '16229213'},
#  {'name': 'Ricky Rubio', 'salary': '16200000'},
#  {'name': 'Jonas Valanciunas', 'salary': '16000000'},
#  {'name': 'Brandon Knight', 'salary': '15643750'},
#  {'name': 'Eric Bledsoe', 'salary': '15625000'},
#  {'name': 'Kelly Oubre', 'salary': '15625000'},
#  {'name': 'Dennis Schroeder', 'salary': '15500000'},
#  {'name': 'Ian Mahinmi', 'salary': '15450051'},
#  {'name': 'James Johnson', 'salary': '15349400'},
#  {'name': 'Marcus Morris', 'salary': '15000000'},
#  {'name': 'Bobby Portis', 'salary': '15000000'},
#  {'name': 'Marvin Williams', 'salary': '14654179'},
#  {'name': 'Danny Green', 'salary': '14634147'},
#  {'name': 'Rudy Gay', 'salary': '14500000'},
#  {'name': 'Cody Zeller', 'salary': '14471910'},
#  {'name': 'Eric Gordon', 'salary': '14057730'},
#  {'name': 'Mason Plumlee', 'salary': '14041096'},
#  {'name': 'JJ Redick', 'salary': '13486300'},
#  {'name': 'Jordan Clarkson', 'salary': '13437500'},
#  {'name': 'Dewayne Dedmon', 'salary': '13333334'},
#  {'name': 'Solomon Hill', 'salary': '13290395'},
#  {'name': 'Justise Winslow', 'salary': '13000000'},
#  {'name': 'Thaddeus Young', 'salary': '12900000'},
#  {'name': 'Michael Kidd-Gilchrist', 'salary': '12784359'},
#  {'name': 'Will Barton', 'salary': '12776786'},
#  {'name': 'Courtney Lee', 'salary': '12759670'},
#  {'name': 'Larry Nance Jr', 'salary': '12727273'},
#  {'name': 'Kelly Olynyk', 'salary': '12667885'},
#  {'name': 'Dion Waiters', 'salary': '12603656'},
#  {'name': 'Marcus Smart', 'salary': '12553571'},
#  {'name': 'Terrence Ross', 'salary': '12500000'},
#  {'name': 'Miles Plumlee', 'salary': '12500000'},
#  {'name': 'Patrick Mills', 'salary': '12428571'},
#  {'name': 'Patrick Beverley', 'salary': '12345680'},
#  {'name': 'Trevor Ariza', 'salary': '12200000'},
#  {'name': 'Brook Lopez', 'salary': '12093024'},
#  {'name': 'Jusuf Nurkic', 'salary': '12000000'},
#  {'name': 'Cory Joseph', 'salary': '12000000'},
#  {'name': 'Joe Ingles', 'salary': '11454546'},
#  {'name': 'Tony Snell', 'salary': '11392857'},
#  {'name': 'Robert Covington', 'salary': '11301219'},
#  {'name': 'Meyers Leonard', 'salary': '11286515'},
#  {'name': 'Moe Harkless', 'salary': '11011234'},
#  {'name': 'TJ Warren', 'salary': '10810000'},
#  {'name': 'Andre Roberson', 'salary': '10740740'},
#  {'name': 'Spencer Dinwiddie', 'salary': '10605600'},
#  {'name': 'Jeremy Lamb', 'salary': '10500000'},
#  {'name': 'Dwight Powell', 'salary': '10259375'},
#  {'name': 'George Hill', 'salary': '10133907'},
#  {'name': 'Josh Richardson', 'salary': '10116576'},
#  {'name': 'Norman Powell', 'salary': '10116576'},
#  {'name': 'Tomas Satoransky', 'salary': '10000000'},
#  {'name': 'DeAndre Jordan', 'salary': '9881598'},
#  {'name': 'Zion Williamson', 'salary': '9757440'},
#  {'name': 'Markelle Fultz', 'salary': '9745200'},
#  {'name': 'John Henson', 'salary': '9732396'},
#  {'name': 'Matthew Dellavedova', 'salary': '9607500'},
#  {'name': 'Dante Exum', 'salary': '9600000'},
#  {'name': 'Deandre Ayton', 'salary': '9562920'},
#  {'name': 'Delon Wright', 'salary': '9473684'},
#  {'name': 'Jerami Grant', 'salary': '9346153'},
#  {'name': 'Fred VanVleet', 'salary': '9346153'},
#  {'name': 'Al-Farouq Aminu', 'salary': '9258000'},
#  {'name': 'Tyus Jones', 'salary': '9258000'},
#  {'name': 'Kyle Anderson', 'salary': '9073050'},
#  {'name': 'Taj Gibson', 'salary': '9000000'},
#  {'name': 'Ja Morant', 'salary': '8730240'},
#  {'name': 'CJ Miles', 'salary': '8730158'},
#  {'name': 'Lonzo Ball', 'salary': '8719320'},
#  {'name': "E'Twaun Moore", 'salary': '8664928'},
#  {'name': 'Marvin Bagley', 'salary': '8556120'},
#  {'name': 'Bogdan Bogdanovic', 'salary': '8529386'},
#  {'name': 'PJ Tucker', 'salary': '8349039'},
#  {'name': 'Cristiano Felicio', 'salary': '8156500'},
#  {'name': 'Ben Simmons', 'salary': '8113929'},
#  {'name': 'Kentavious Caldwell-Pope', 'salary': '8089282'},
#  {'name': 'Thomas Bryant', 'salary': '8000000'},
#  {'name': 'Maxi Kleber', 'salary': '8000000'},
#  {'name': 'Louis Williams', 'salary': '8000000'},
#  {'name': 'Wayne Ellington', 'salary': '8000000'},
#  {'name': 'Elfrid Payton', 'salary': '8000000'},
#  {'name': 'RJ Barrett', 'salary': '7839960'},
#  {'name': 'Jayson Tatum', 'salary': '7830000'},
#  {'name': 'Jae Crowder', 'salary': '7815533'},
#  {'name': 'Luka Doncic', 'salary': '7683360'},
#  {'name': 'Joe Harris', 'salary': '7666667'},
#  {'name': 'Seth Curry', 'salary': '7461380'},
#  {'name': 'DeMarre Carroll', 'salary': '7339258'},
#  {'name': 'Doug McDermott', 'salary': '7333333'},
#  {'name': 'Langston Galloway', 'salary': '7333333'},
#  {'name': 'Derrick Rose', 'salary': '7317074'},
#  {'name': 'Brandon Ingram', 'salary': '7265485'},
#  {'name': 'Darius Miller', 'salary': '7250000'},
#  {'name': 'DJ Augustin', 'salary': '7250000'},
#  {'name': "De'Andre Hunter", 'salary': '7068360'},
#  {'name': 'Josh Jackson', 'salary': '7059480'},
#  {'name': 'Ersan Ilyasova', 'salary': '7000000'},
#  {'name': 'Davis Bertans', 'salary': '7000000'},
#  {'name': 'Jaren Jackson', 'salary': '6927480'},
#  {'name': 'Nemanja Bjelica', 'salary': '6825000'},
#  {'name': 'Avery Bradley', 'salary': '6767000'},
#  {'name': 'Joakim Noah', 'salary': '6576567'},
#  {'name': 'Jaylen Brown', 'salary': '6534829'},
#  {'name': 'Jabari Parker', 'salary': '6500000'},
#  {'name': 'Ivica Zubac', 'salary': '6481482'},
#  {'name': 'Darius Garland', 'salary': '6400920'},
#  {'name': "De'Aaron Fox", 'salary': '6392760'},
#  {'name': 'Trae Young', 'salary': '6273000'},
#  {'name': 'Kyle Korver', 'salary': '6004753'},
#  {'name': 'Ishmael Smith', 'salary': '6000000'},
#  {'name': 'Montrezl Harrell', 'salary': '6000000'},
#  {'name': 'Marco Belinelli', 'salary': '5846154'},
#  {'name': 'Jarrett Culver', 'salary': '5813640'},
#  {'name': 'Jonathan Isaac', 'salary': '5806440'},
#  {'name': 'Rodney Hood', 'salary': '5718000'},
#  {'name': 'Ryan Anderson', 'salary': '5714583'},
#  {'name': 'Mo Bamba', 'salary': '5697600'},
#  {'name': 'Dwight Howard', 'salary': '5603850'},
#  {'name': 'Timofey Mozgov', 'salary': '5573333'},
#  {'name': 'Pau Gasol', 'salary': '5538540'},
#  {'name': 'Trey Lyles', 'salary': '5500000'},
#  {'name': 'Deron Williams', 'salary': '5474787'},
#  {'name': 'Aron Baynes', 'salary': '5453280'},
#  {'name': 'Kris Dunn', 'salary': '5348007'},
#  {'name': 'Josh Smith', 'salary': '5331729'},
#  {'name': 'Coby White', 'salary': '5307120'},
#  {'name': 'Lauri Markkanen', 'salary': '5300400'},
#  {'name': 'Wendell Carter', 'salary': '5201400'},
#  {'name': 'Luol Deng', 'salary': '5000000'},
#  {'name': 'Daniel Theis', 'salary': '5000000'},
#  {'name': 'Jaxson Hayes', 'salary': '4862040'},
#  {'name': 'Buddy Hield', 'salary': '4861207'},
#  {'name': 'Frank Ntilikina', 'salary': '4855800'},
#  {'name': 'Rodney McGruder', 'salary': '4807693'},
#  {'name': 'Enes Kanter', 'salary': '4767000'},
#  {'name': 'JaMychal Green', 'salary': '4767000'},
#  {'name': 'Robin Lopez', 'salary': '4767000'},
#  {'name': 'Mike Scott', 'salary': '4767000'},
#  {'name': 'Richaun Holmes', 'salary': '4767000'},
#  {'name': 'Ed Davis', 'salary': '4767000'},
#  {'name': 'Garrett Temple', 'salary': '4767000'},
#  {'name': 'Justin Holiday', 'salary': '4767000'},
#  {'name': 'Frank Kaminsky', 'salary': '4767000'},
#  {'name': 'Collin Sexton', 'salary': '4764960'},
#  {'name': 'Rui Hachimura', 'salary': '4469160'},
#  {'name': 'Kevon Looney', 'salary': '4464286'},
#  {'name': 'Dennis Smith', 'salary': '4463640'},
#  {'name': 'Jamal Murray', 'salary': '4444746'},
#  {'name': 'Kevin Knox', 'salary': '4380120'},
#  {'name': 'Cam Reddish', 'salary': '4245720'},
#  {'name': 'Zach Collins', 'salary': '4240200'},
#  {'name': 'Mikal Bridges', 'salary': '4161000'},
#  {'name': 'Alex Len', 'salary': '4160000'},
#  {'name': 'Nicolo Melli', 'salary': '4102564'},
#  {'name': 'Cameron Johnson', 'salary': '4033440'},
#  {'name': 'Malik Monk', 'salary': '4028400'},
#  {'name': 'JaVale McGee', 'salary': '4000000'},
#  {'name': 'Reggie Bullock', 'salary': '4000000'},
#  {'name': 'Dorian Finney-Smith', 'salary': '4000000'},
#  {'name': 'Patrick McCaw', 'salary': '4000000'},
#  {'name': 'Shai Gilgeous-Alexander', 'salary': '3952920'},
#  {'name': 'PJ Washington', 'salary': '3831840'},
#  {'name': 'Luke Kennard', 'salary': '3827160'},
#  {'name': 'Miles Bridges', 'salary': '3755400'},
#  {'name': 'Jakob Poeltl', 'salary': '3754885'},
#  {'name': 'Markieff Morris', 'salary': '3709887'},
#  {'name': 'Tyler Herro', 'salary': '3640200'},
#  {'name': 'Donovan Mitchell', 'salary': '3635760'},
#  {'name': 'Stanley Johnson', 'salary': '3623000'},
#  {'name': 'Jake Layman', 'salary': '3581986'},
#  {'name': 'Thon Maker', 'salary': '3569643'},
#  {'name': 'Jerome Robinson', 'salary': '3567720'},
#  {'name': 'Allonzo Trier', 'salary': '3551100'},
#  {'name': 'Danuel House', 'salary': '3540000'},
#  {'name': 'Domantas Sabonis', 'salary': '3529554'},
#  {'name': 'Boban Marjanovic', 'salary': '3500000'},
#  {'name': 'TJ McConnell', 'salary': '3500000'},
#  {'name': 'DeMarcus Cousins', 'salary': '3500000'},
#  {'name': 'Taurean Prince', 'salary': '3481985'},
#  {'name': 'Dario Saric', 'salary': '3481985'},
#  {'name': 'Romeo Langford', 'salary': '3458400'},
#  {'name': 'Bam Adebayo', 'salary': '3454080'},
#  {'name': 'Jeff Green', 'salary': '3405180'},
#  {'name': 'Michael Porter', 'salary': '3389400'},
#  {'name': 'Denzel Valentine', 'salary': '3377568'},
#  {'name': 'Juan Hernangomez', 'salary': '3321029'},
#  {'name': 'Sekou Doumbouya', 'salary': '3285120'},
#  {'name': 'Justin Jackson', 'salary': '3280920'},
#  {'name': 'Troy Brown', 'salary': '3219480'},
#  {'name': 'Jon Leuer', 'salary': '3169348'},
#  {'name': 'Yogi Ferrell', 'salary': '3150000'},
#  {'name': 'Patrick Patterson', 'salary': '3068660'},
#  {'name': 'Zhaire Smith', 'salary': '3058800'},
#  {'name': 'Ryan Arcidiacono', 'salary': '3000000'},
#  {'name': 'Quinn Cook', 'salary': '3000000'},
#  {'name': 'Khem Birch', 'salary': '3000000'},
#  {'name': 'Omer Asik', 'salary': '3000000'},
#  {'name': 'Nickeil Alexander-Walker', 'salary': '2964840'},
#  {'name': 'DJ Wilson', 'salary': '2961120'},
#  {'name': 'Cedi Osman', 'salary': '2907143'},
#  {'name': 'Donte DiVincenzo', 'salary': '2905800'},
#  {'name': 'Bryn Forbes', 'salary': '2875000'},
#  {'name': 'Andrew Nicholson', 'salary': '2844429'},
#  {'name': 'Goga Bitadze', 'salary': '2816760'},
#  {'name': 'TJ Leaf', 'salary': '2813280'},
#  {'name': 'Lonnie Walker', 'salary': '2764200'},
#  {'name': 'Alex Caruso', 'salary': '2750000'},
#  {'name': 'Malik Beasley', 'salary': '2731713'},
#  {'name': 'Luka Samanic', 'salary': '2689920'},
#  {'name': 'John Collins', 'salary': '2686560'},
#  {'name': 'Kevin Huerter', 'salary': '2636280'},
#  {'name': 'Caris LeVert', 'salary': '2625717'},
#  {'name': 'Marko Guduric', 'salary': '2625000'},
#  {'name': 'DeAndre Bembry', 'salary': '2603981'},
#  {'name': 'Matisse Thybulle', 'salary': '2582160'},
#  {'name': 'Harry Giles', 'salary': '2578800'},
#  {'name': 'Rajon Rondo', 'salary': '2564753'},
#  {'name': 'Wesley Matthews', 'salary': '2564753'},
#  {'name': 'Vince Carter', 'salary': '2564753'},
#  {'name': 'Nenê', 'salary': '2564753'},
#  {'name': 'Wilson Chandler', 'salary': '2564753'},
#  {'name': 'Jose Juan Barea', 'salary': '2564753'},
#  {'name': 'Gerald Green', 'salary': '2564753'},
#  {'name': 'Tyson Chandler', 'salary': '2564753'},
#  {'name': 'Thabo Sefolosha', 'salary': '2564753'},
#  {'name': 'Jared Dudley', 'salary': '2564753'},
#  {'name': 'Anthony Tolliver', 'salary': '2564753'},
#  {'name': 'Udonis Haslem', 'salary': '2564753'},
#  {'name': 'Josh Okogie', 'salary': '2530680'},
#  {'name': 'Vincent Poirier', 'salary': '2505793'},
#  {'name': 'Rondae Hollis-Jefferson', 'salary': '2500000'},
#  {'name': 'Troy Daniels', 'salary': '2487033'},
#  {'name': 'Brandon Clarke', 'salary': '2478840'},
#  {'name': 'Terrance Ferguson', 'salary': '2475840'},
#  {'name': 'Grayson Allen', 'salary': '2429400'},
#  {'name': 'Alfonzo McKinnie', 'salary': '2391985'},
#  {'name': 'Grant Williams', 'salary': '2379840'},
#  {'name': 'Jarrett Allen', 'salary': '2376840'},
#  {'name': 'Pascal Siakam', 'salary': '2351838'},
#  {'name': 'Skal Labissiere', 'salary': '2338846'},
#  {'name': 'Chandler Hutchison', 'salary': '2332320'},
#  {'name': 'Dejounte Murray', 'salary': '2321735'},
#  {'name': 'Isaiah Thomas', 'salary': '2320044'},
#  {'name': 'Alec Burks', 'salary': '2320044'},
#  {'name': 'Damian Jones', 'salary': '2305057'},
#  {'name': 'Darius Bazley', 'salary': '2284800'},
#  {'name': 'OG Anunoby', 'salary': '2281800'},
#  {'name': 'Ante Zizic', 'salary': '2281800'},
#  {'name': 'Luke Kornet', 'salary': '2250000'},
#  {'name': 'Monta Ellis', 'salary': '2245400'},
#  {'name': 'Aaron Holiday', 'salary': '2239200'},
#  {'name': 'Ty Jerome', 'salary': '2193480'},
#  {'name': 'Willie Cauley-Stein', 'salary': '2177483'},
#  {'name': "Kyle O'Quinn", 'salary': '2174318'},
#  {'name': 'Austin Rivers', 'salary': '2174310'},
#  {'name': 'Carmelo Anthony', 'salary': '2159029'},
#  {'name': 'Anfernee Simons', 'salary': '2149560'},
#  {'name': 'Matt Barnes', 'salary': '2133542'},
#  {'name': 'Nassir Little', 'salary': '2105520'},
#  {'name': 'Moritz Wagner', 'salary': '2063520'},
#  {'name': 'Dylan Windler', 'salary': '2035800'},
#  {'name': 'Caleb Swanigan', 'salary': '2033160'},
#  {'name': 'Ben McLemore', 'salary': '2028594'},
#  {'name': 'Mike Muscala', 'salary': '2028594'},
#  {'name': 'Michael Carter-Williams', 'salary': '2028594'},
#  {'name': 'Trey Burke', 'salary': '2028594'},
#  {'name': 'Spencer Hawes', 'salary': '2007058'},
#  {'name': 'Edmond Sumner', 'salary': '2000000'},
#  {'name': 'Torrey Craig', 'salary': '2000000'},
#  {'name': 'Noah Vonleh', 'salary': '2000000'},
#  {'name': 'Landry Shamet', 'salary': '1995120'},
#  {'name': 'Mfiondu Kabengele', 'salary': '1977000'},
#  {'name': 'Kyle Kuzma', 'salary': '1974600'},
#  {'name': 'Jordan Poole', 'salary': '1964760'},
#  {'name': 'Tony Bradley', 'salary': '1962360'},
#  {'name': 'Keldon Johnson', 'salary': '1950600'},
#  {'name': 'Derrick White', 'salary': '1948080'},
#  {'name': 'Robert Williams', 'salary': '1937520'},
#  {'name': 'Josh Hart', 'salary': '1934160'},
#  {'name': 'Jacob Evans', 'salary': '1925880'},
#  {'name': 'Anderson Varejao', 'salary': '1913345'},
#  {'name': 'Dzanan Musa', 'salary': '1911600'},
#  {'name': 'Omari Spellman', 'salary': '1897800'},
#  {'name': 'James Ennis', 'salary': '1882867'},
#  {'name': 'Nerlens Noel', 'salary': '1882867'},
#  {'name': 'Glenn Robinson III', 'salary': '1882867'},
#  {'name': 'Dragan Bender', 'salary': '1868554'},
#  {'name': 'Larry Sanders', 'salary': '1865546'},
#  {'name': 'Bruno Caboclo', 'salary': '1845301'},
#  {'name': 'Shabazz Napier', 'salary': '1845301'},
#  {'name': 'Jonah Bolden', 'salary': '1788296'},
#  {'name': 'Mario Hezonja', 'salary': '1737145'},
#  {'name': 'JaKarr Sampson', 'salary': '1737145'},
#  {'name': 'Raul Neto', 'salary': '1737145'},
#  {'name': 'Emmanuel Mudiay', 'salary': '1737145'},
#  {'name': 'Pat Connaughton', 'salary': '1723050'},
#  {'name': 'Jahlil Okafor', 'salary': '1702486'},
#  {'name': 'Rodions Kurucs', 'salary': '1699236'},
#  {'name': 'David Nwaba', 'salary': '1678854'},
#  {'name': 'Cheick Diallo', 'salary': '1678854'},
#  {'name': 'Willy Hernangomez', 'salary': '1676735'},
#  {'name': 'Georges Niang', 'salary': '1645357'},
#  {'name': 'Treveon Graham', 'salary': '1645357'},
#  {'name': 'Christian Wood', 'salary': '1645357'},
#  {'name': 'Derrick Jones', 'salary': '1645357'},
#  {'name': 'Furkan Korkmaz', 'salary': '1620564'},
#  {'name': 'Shaquille Harrison', 'salary': '1620564'},
#  {'name': 'Justin Patton', 'salary': '1620564'},
#  {'name': 'Tim Frazier', 'salary': '1620564'},
#  {'name': 'Jordan Bell', 'salary': '1620564'},
#  {'name': 'Dillon Brooks', 'salary': '1618520'},
#  {'name': "Royce O'Neale", 'salary': '1618520'},
#  {'name': 'Abdel Nader', 'salary': '1618520'},
#  {'name': 'Semi Ojeleye', 'salary': '1618520'},
#  {'name': 'Dwayne Bacon', 'salary': '1618520'},
#  {'name': 'Sterling Brown', 'salary': '1618520'},
#  {'name': 'Frank Jackson', 'salary': '1618520'},
#  {'name': 'Damyean Dotson', 'salary': '1618520'},
#  {'name': 'Wesley Iwundu', 'salary': '1618520'},
#  {'name': 'Jabari Bird', 'salary': '1588231'},
#  {'name': 'Monte Morris', 'salary': '1588231'},
#  {'name': 'Chris Boucher', 'salary': '1588231'},
#  {'name': 'Malcolm Miller', 'salary': '1588231'},
#  {'name': 'Mitchell Robinson', 'salary': '1559712'},
#  {'name': 'Amile Jefferson', 'salary': '1529007'},
#  {'name': 'Derrick Walton', 'salary': '1527375'},
#  {'name': 'Isaiah Roby', 'salary': '1500000'},
#  {'name': 'Nigel Williams-Goss', 'salary': '1500000'},
#  {'name': 'Antonio Blakeney', 'salary': '1488231'},
#  {'name': 'JR Smith', 'salary': '1456667'},
#  {'name': 'Thanasis Antetokounmpo', 'salary': '1445697'},
#  {'name': 'Shake Milton', 'salary': '1445697'},
#  {'name': 'Brad Wanamaker', 'salary': '1445697'},
#  {'name': 'Theo Pinson', 'salary': '1445697'},
#  {'name': 'Wenyen Gabriel', 'salary': '1445697'},
#  {'name': 'Gary Clark', 'salary': '1427191'},
#  {'name': 'Khyri Thomas', 'salary': '1416852'},
#  {'name': 'Isaiah Hartenstein', 'salary': '1416852'},
#  {'name': 'Deonte Burton', 'salary': '1416852'},
#  {'name': 'Elie Okobo', 'salary': '1416852'},
#  {'name': 'Gary Trent Jr', 'salary': '1416852'},
#  {'name': 'Isaac Bonga', 'salary': '1416852'},
#  {'name': 'Devonte Graham', 'salary': '1416852'},
#  {'name': 'Ryan Broekhoff', 'salary': '1416852'},
#  {'name': 'Jalen Brunson', 'salary': '1416852'},
#  {'name': 'Keita Bates-Diop', 'salary': '1416852'},
#  {'name': 'Bruce Brown', 'salary': '1416852'},
#  {'name': 'Sviatoslav Mykhailiuk', 'salary': '1416852'},
#  {'name': 'Alize Johnson', 'salary': '1416852'},
#  {'name': "De'Anthony Melton", 'salary': '1416852'},
#  {'name': 'Kendrick Nunn', 'salary': '1416852'},
#  {'name': 'Duncan Robinson', 'salary': '1416852'},
#  {'name': 'Jarred Vanderbilt', 'salary': '1416852'},
#  {'name': 'Kenrich Williams', 'salary': '1416852'},
#  {'name': 'Hamidou Diallo', 'salary': '1416852'},
#  {'name': 'Melvin Frazier', 'salary': '1416852'},
#  {'name': 'Jevon Carter', 'salary': '1416852'},
#  {'name': 'Chimezie Metu', 'salary': '1416852'},
#  {'name': 'Marquese Chriss', 'salary': '1413273'},
#  {'name': 'Bruno Fernando', 'salary': '1400000'},
#  {'name': 'Jaylen Nowell', 'salary': '1400000'},
#  {'name': 'Kevin Porter', 'salary': '1290960'},
#  {'name': 'Jordan McRae', 'salary': '1254933'},
#  {'name': 'Carsen Edwards', 'salary': '1228026'},
#  {'name': 'Cody Martin', 'salary': '1173310'},
#  {'name': 'Gary Payton II', 'salary': '1052909'},
#  {'name': 'Guerschon Yabusele', 'salary': '1039080'},
#  {'name': 'Terance Mann', 'salary': '1000000'},
#  {'name': 'Admiral Schofield', 'salary': '1000000'},
#  {'name': 'Justin Hamilton', 'salary': '1000000'},
#  {'name': 'Jonathon Simmons', 'salary': '1000000'},
#  {'name': 'Kyle Singler', 'salary': '999200'},
#  {'name': 'Vlatko Cancar', 'salary': '898310'},
#  {'name': 'Javonte Green', 'salary': '898310'},
#  {'name': 'Nicolas Claxton', 'salary': '898310'},
#  {'name': 'Caleb Martin', 'salary': '898310'},
#  {'name': 'Jalen McDaniels', 'salary': '898310'},
#  {'name': 'Daniel Gafford', 'salary': '898310'},
#  {'name': 'Eric Paschall', 'salary': '898310'},
#  {'name': 'Alen Smailagic', 'salary': '898310'},
#  {'name': 'Talen Horton-Tucker', 'salary': '898310'},
#  {'name': 'KZ Okpala', 'salary': '898310'},
#  {'name': 'Naz Reid', 'salary': '898310'},
#  {'name': 'Ignas Brazdeikis', 'salary': '898310'},
#  {'name': 'Jalen Lecque', 'salary': '898310'},
#  {'name': 'Justin James', 'salary': '898310'},
#  {'name': 'Dewan Hernandez', 'salary': '898310'},
#  {'name': 'Matt Thomas', 'salary': '898310'},
#  {'name': 'DaQuan Jeffries', 'salary': '898310'},
#  {'name': 'Terence Davis', 'salary': '898310'},
#  {'name': 'Miye Oni', 'salary': '898310'},
#  {'name': 'Damion Lee', 'salary': '842327'},
#  {'name': 'Timothe Luwawu', 'salary': '837583'},
#  {'name': 'Raymond Spalding', 'salary': '787994'},
#  {'name': 'Juwan Morgan', 'salary': '746054'},
#  {'name': 'Cole Aldrich', 'salary': '685340'},
#  {'name': 'Shaun Livingston', 'salary': '666666'},
#  {'name': 'Rayjon Tucker', 'salary': '578573'},
#  {'name': 'Chris Clemons', 'salary': '563346'},
#  {'name': 'Brandon Goodwin', 'salary': '522738'},
#  {'name': 'Tyrone Wallace', 'salary': '502491'},
#  {'name': 'Max Strus', 'salary': '494568'},
#  {'name': 'Anzejs Pasecniks', 'salary': '482144'},
#  {'name': 'Chris Silva', 'salary': '466918'},
#  {'name': 'Dakari Johnson', 'salary': '459414'},
#  {'name': 'Ivan Rabb', 'salary': '451326'},
#  {'name': 'Iman Shumpert', 'salary': '419443'},
#  {'name': 'Justin Robinson', 'salary': '395865'},
#  {'name': 'Ky Bowman', 'salary': '350189'},
#  {'name': 'Juan Toscano-Anderson', 'salary': '350189'},
#  {'name': 'Norvel Pelle', 'salary': '350189'},
#  {'name': 'CJ Watson', 'salary': '333333'},
#  {'name': 'Festus Ezeli', 'salary': '333333'},
#  {'name': 'Deyonta Davis', 'salary': '250000'},
#  {'name': 'Stanton Kidd', 'salary': '250000'},
#  {'name': 'Joe Johnson', 'salary': '220000'},
#  {'name': 'Jontay Porter', 'salary': '197932'},
#  {'name': 'Jemerrio Jones', 'salary': '195077'},
#  {'name': 'Mychal Mulder', 'salary': '187782'},
#  {'name': 'Joe Chealey', 'salary': '163356'},
#  {'name': 'Josh Magette', 'salary': '161245'},
#  {'name': 'Johnathan Williams', 'salary': '161245'},
#  {'name': 'Chris Chiozza', 'salary': '159136'},
#  {'name': 'Cameron Payne', 'salary': '150000'},
#  {'name': 'Tyler Cook', 'salary': '131955'},
#  {'name': 'Zach Norvell', 'salary': '130320'},
#  {'name': 'Paul Watson', 'salary': '130319'},
#  {'name': 'Levi Randolph', 'salary': '129568'},
#  {'name': 'Oshae Brissett', 'salary': '129568'},
#  {'name': 'William Howard', 'salary': '129568'},
#  {'name': 'Troy Williams', 'salary': '122741'},
#  {'name': 'JP Macura', 'salary': '106181'},
#  {'name': 'Donta Hall', 'salary': '101504'},
#  {'name': 'Jaylen Adams', 'salary': '100000'},
#  {'name': 'Yante Maten', 'salary': '100000'},
#  {'name': 'Demetrius Jackson', 'salary': '92857'},
#  {'name': 'Justin Anderson', 'salary': '91557'},
#  {'name': 'Jeremy Pargo', 'salary': '91557'},
#  {'name': 'Chasson Randle', 'salary': '91557'},
#  {'name': 'Sheldon Mac', 'salary': '81678'},
#  {'name': 'Dusty Hannahs', 'salary': '81678'},
#  {'name': 'Jarrod Uthoff', 'salary': '81678'},
#  {'name': 'Charlie Brown', 'salary': '79568'},
#  {'name': 'Tacko Fall', 'salary': '79568'},
#  {'name': 'Tremont Waters', 'salary': '79568'},
#  {'name': 'Henry Ellenson', 'salary': '79568'},
#  {'name': 'Jeremiah Martin', 'salary': '79568'},
#  {'name': 'Robert Franks', 'salary': '79568'},
#  {'name': 'Kobi Simmons', 'salary': '79568'},
#  {'name': 'Adam Mokoka', 'salary': '79568'},
#  {'name': 'Matt Mooney', 'salary': '79568'},
#  {'name': 'Dean Wade', 'salary': '79568'},
#  {'name': 'Antonius Cleveland', 'salary': '79568'},
#  {'name': 'Josh Reaves', 'salary': '79568'},
#  {'name': 'Bol Bol', 'salary': '79568'},
#  {'name': 'PJ Dozier', 'salary': '79568'},
#  {'name': 'Jordan Bone', 'salary': '79568'},
#  {'name': 'Louis King', 'salary': '79568'},
#  {'name': 'Michael Frazier', 'salary': '79568'},
#  {'name': 'Brian Bowen', 'salary': '79568'},
#  {'name': 'Naz Long', 'salary': '79568'},
#  {'name': 'Amir Coffey', 'salary': '79568'},
#  {'name': 'Johnathan Motley', 'salary': '79568'},
#  {'name': 'Kostas Antetokounmpo', 'salary': '79568'},
#  {'name': 'Devontae Cacok', 'salary': '79568'},
#  {'name': 'John Konchar', 'salary': '79568'},
#  {'name': 'Yuta Watanabe', 'salary': '79568'},
#  {'name': 'Kyle Alexander', 'salary': '79568'},
#  {'name': 'Daryl Macon', 'salary': '79568'},
#  {'name': 'Gabe Vincent', 'salary': '79568'},
#  {'name': 'Frank Mason', 'salary': '79568'},
#  {'name': 'Cam Reynolds', 'salary': '79568'},
#  {'name': 'Jordan McLaughlin', 'salary': '79568'},
#  {'name': 'Kelan Martin', 'salary': '79568'},
#  {'name': 'Zylan Cheatham', 'salary': '79568'},
#  {'name': 'Josh Gray', 'salary': '79568'},
#  {'name': 'Kadeem Allen', 'salary': '79568'},
#  {'name': 'Kenny Wooten', 'salary': '79568'},
#  {'name': 'Luguentz Dort', 'salary': '79568'},
#  {'name': 'Devon Hall', 'salary': '79568'},
#  {'name': 'Kevin Hervey', 'salary': '79568'},
#  {'name': 'BJ Johnson', 'salary': '79568'},
#  {'name': 'Vic Law', 'salary': '79568'},
#  {'name': 'Marial Shayok', 'salary': '79568'},
#  {'name': 'Jared Harper', 'salary': '79568'},
#  {'name': 'Tariq Owens', 'salary': '79568'},
#  {'name': 'Moses Brown', 'salary': '79568'},
#  {'name': 'Jaylen Hoard', 'salary': '79568'},
#  {'name': 'Kyle Guy', 'salary': '79568'},
#  {'name': 'Drew Eubanks', 'salary': '79568'},
#  {'name': 'Quinndary Weatherspoon', 'salary': '79568'},
#  {'name': 'Shamorie Ponds', 'salary': '79568'},
#  {'name': 'Jarrell Brantley', 'salary': '79568'},
#  {'name': 'Justin Wright-Foreman', 'salary': '79568'},
#  {'name': 'Garrison Mathews', 'salary': '79568'},
#  {'name': 'Malik Newman', 'salary': '65978'},
#  {'name': "Sir'Dominic Pointer", 'salary': '50752'},
#  {'name': 'Marques Bolden', 'salary': '50751'},
#  {'name': 'Eric Mika', 'salary': '50751'},
#  {'name': 'Tyler Lydon', 'salary': '50000'},
#  {'name': 'Tyler Ulis', 'salary': '50000'},
#  {'name': 'Isaiah Taylor', 'salary': '50000'}]

# %% [markdown]
# ### Function to Scrape Salaries

# %%
def salaryextract(year):
    url = "https://hoopshype.com/salaries/players/" + str(year-1) + "-" + str(year) + "/"
    req = requests.get(url)
    if req.status_code != 200:
        print (f'{url} failed. Status code {req.status_code}')
    html = req.text
    soup = BeautifulSoup(html, 'lxml')
    seasonsalary = []
    all_td = soup.find_all('td')
    for element in all_td:
        result = {}
        a_href = element.find('a')
        if a_href:
            result['name'] = a_href.text.strip()
            result['salary'] = element.find_next('td').attrs['data-value']

        if len(result) == 2:
            seasonsalary.append(result)
    return seasonsalary

# %%
# salary2019 = salaryextract(2019)
# salary2018 = salaryextract(2018)
salary2017 = salaryextract(2017)
time.sleep(5)
salary2016 = salaryextract(2016)
time.sleep(5)
salary2015 = salaryextract(2015)
time.sleep(10)
salary2014 = salaryextract(2014)
time.sleep(5)
salary2013 = salaryextract(2013)
time.sleep(5)
salary2012 = salaryextract(2012)
time.sleep(10)
salary2011 = salaryextract(2011)
time.sleep(5)
salary2010 = salaryextract(2010)
time.sleep(5)
salary2009 = salaryextract(2009)
time.sleep(10)
salary2008 = salaryextract(2008)
# Out:
# https://hoopshype.com/salaries/players/2010-2011/ failed. Status code 504

# %%
# hoopshype is timing out for this year's data. Error is on server side.
salary2011 = salaryextract(2011)

# %%
salary2011
# Out:
# [{'name': 'Kobe Bryant', 'salary': '24806250'},
#  {'name': 'Rashard Lewis', 'salary': '19573711'},
#  {'name': 'Kevin Garnett', 'salary': '18800000'},
#  {'name': 'Tim Duncan', 'salary': '18700000'},
#  {'name': 'Michael Redd', 'salary': '18300000'},
#  {'name': 'Pau Gasol', 'salary': '17823000'},
#  {'name': 'Andrei Kirilenko', 'salary': '17823000'},
#  {'name': 'Gilbert Arenas', 'salary': '17730694'},
#  {'name': 'Yao Ming', 'salary': '17686100'},
#  {'name': 'Zach Randolph', 'salary': '17666666'},
#  {'name': 'Vince Carter', 'salary': '17300000'},
#  {'name': 'Dirk Nowitzki', 'salary': '17278618'},
#  {'name': 'Carmelo Anthony', 'salary': '17149243'},
#  {'name': 'Dwight Howard', 'salary': '16647180'},
#  {'name': 'Kenyon Martin', 'salary': '16545454'},
#  {'name': 'Amare Stoudemire', 'salary': '16486611'},
#  {'name': 'Joe Johnson', 'salary': '16324500'},
#  {'name': 'Elton Brand', 'salary': '15959099'},
#  {'name': 'Predrag Stojakovic', 'salary': '15532320'},
#  {'name': 'Chris Paul', 'salary': '14940153'},
#  {'name': 'Deron Williams', 'salary': '14940152'},
#  {'name': 'LeBron James', 'salary': '14500000'},
#  {'name': 'Chris Bosh', 'salary': '14500000'},
#  {'name': 'Jason Richardson', 'salary': '14444444'},
#  {'name': 'Carlos Boozer', 'salary': '14400000'},
#  {'name': 'Dwyane Wade', 'salary': '14200000'},
#  {'name': 'Paul Pierce', 'salary': '13876321'},
#  {'name': 'Andrew Bynum', 'salary': '13700000'},
#  {'name': 'Rudy Gay', 'salary': '13603750'},
#  {'name': 'Brandon Roy', 'salary': '13520500'},
#  {'name': 'Tony Parker', 'salary': '13500000'},
#  {'name': 'Samuel Dalembert', 'salary': '13428129'},
#  {'name': 'Antawn Jamison', 'salary': '13358905'},
#  {'name': 'Nick Collison', 'salary': '13250000'},
#  {'name': 'Chauncey Billups', 'salary': '13150000'},
#  {'name': 'Baron Davis', 'salary': '13000000'},
#  {'name': 'Al Jefferson', 'salary': '13000000'},
#  {'name': 'Tyson Chandler', 'salary': '12600000'},
#  {'name': 'Richard Hamilton', 'salary': '12500000'},
#  {'name': 'Andre Iguodala', 'salary': '12345250'},
#  {'name': 'Troy Murphy', 'salary': '11968253'},
#  {'name': 'Manu Ginobili', 'salary': '11854584'},
#  {'name': 'Chris Kaman', 'salary': '11800000'},
#  {'name': 'Marcus Camby', 'salary': '11749832'},
#  {'name': 'Josh Smith', 'salary': '11600000'},
#  {'name': 'Eddy Curry', 'salary': '11530592'},
#  {'name': 'Emeka Okafor', 'salary': '11495000'},
#  {'name': 'Nenê', 'salary': '11360000'},
#  {'name': 'Luol Deng', 'salary': '11345000'},
#  {'name': 'LaMarcus Aldridge', 'salary': '11244000'},
#  {'name': 'Tayshaun Prince', 'salary': '11148760'},
#  {'name': 'Kevin Martin', 'salary': '11100005'},
#  {'name': 'Monta Ellis', 'salary': '11000000'},
#  {'name': 'Andrew Bogut', 'salary': '11000000'},
#  {'name': 'Danny Granger', 'salary': '10973202'},
#  {'name': 'Jamal Crawford', 'salary': '10800000'},
#  {'name': 'Ben Gordon', 'salary': '10800000'},
#  {'name': 'David Lee', 'salary': '10800000'},
#  {'name': 'Jason Terry', 'salary': '10650000'},
#  {'name': 'Mike Dunleavy', 'salary': '10561984'},
#  {'name': 'Caron Butler', 'salary': '10561960'},
#  {'name': 'Gerald Wallace', 'salary': '10500000'},
#  {'name': 'Steve Nash', 'salary': '10310938'},
#  {'name': 'Hidayet Turkoglu', 'salary': '10215850'},
#  {'name': 'Ray Allen', 'salary': '10000000'},
#  {'name': 'Mehmet Okur', 'salary': '9945000'},
#  {'name': 'Corey Maggette', 'salary': '9600000'},
#  {'name': 'Maurice Williams', 'salary': '9300000'},
#  {'name': 'Rajon Rondo', 'salary': '9090911'},
#  {'name': 'Kirk Hinrich', 'salary': '9000000'},
#  {'name': 'Boris Diaw', 'salary': '9000000'},
#  {'name': 'Andris Biedrins', 'salary': '9000000'},
#  {'name': 'Jose Calderon', 'salary': '9000000'},
#  {'name': 'Devin Harris', 'salary': '8981000'},
#  {'name': 'Jason Kidd', 'salary': '8610500'},
#  {'name': 'TJ Ford', 'salary': '8500000'},
#  {'name': 'Andrea Bargnani', 'salary': '8500000'},
#  {'name': 'Stephen Jackson', 'salary': '8453250'},
#  {'name': 'Richard Jefferson', 'salary': '8400000'},
#  {'name': 'David West', 'salary': '8287500'},
#  {'name': 'Lamar Odom', 'salary': '8200000'},
#  {'name': 'John Salmons', 'salary': '8000000'},
#  {'name': 'Jameer Nelson', 'salary': '7800000'},
#  {'name': 'Luis Scola', 'salary': '7775378'},
#  {'name': 'Marko Jaric', 'salary': '7625000'},
#  {'name': 'Paul Millsap', 'salary': '7600000'},
#  {'name': 'Raymond Felton', 'salary': '7500000'},
#  {'name': 'Joel Przybilla', 'salary': '7405300'},
#  {'name': 'Shane Battier', 'salary': '7354500'},
#  {'name': 'Shawn Marion', 'salary': '7305500'},
#  {'name': 'Anderson Varejao', 'salary': '7281818'},
#  {'name': 'Andre Miller', 'salary': '7269264'},
#  {'name': 'JJ Redick', 'salary': '7250000'},
#  {'name': 'Dan Gadzuric', 'salary': '7248325'},
#  {'name': 'James Posey', 'salary': '7148800'},
#  {'name': 'Leandro Barbosa', 'salary': '7100000'},
#  {'name': 'Charlie Villanueva', 'salary': '7020000'},
#  {'name': 'Travis Outlaw', 'salary': '7000000'},
#  {'name': 'Brendan Haywood', 'salary': '6900000'},
#  {'name': 'Vladimir Radmanovic', 'salary': '6883800'},
#  {'name': 'Jared Jeffries', 'salary': '6883800'},
#  {'name': 'Nazr Mohammed', 'salary': '6883800'},
#  {'name': 'Andres Nocioni', 'salary': '6850000'},
#  {'name': 'Greg Oden', 'salary': '6760524'},
#  {'name': 'JR Smith', 'salary': '6757851'},
#  {'name': 'Marvin Williams', 'salary': '6712500'},
#  {'name': 'Morris Peterson', 'salary': '6665000'},
#  {'name': 'Jeff Foster', 'salary': '6655000'},
#  {'name': 'Jason Kapono', 'salary': '6641440'},
#  {'name': 'Tyrus Thomas', 'salary': '6611570'},
#  {'name': 'Josh Childress', 'salary': '6500000'},
#  {'name': 'DeSagana Diop', 'salary': '6478600'},
#  {'name': 'Beno Udrih', 'salary': '6478600'},
#  {'name': 'Rasheed Wallace', 'salary': '6322320'},
#  {'name': 'Metta World Peace', 'salary': '6322320'},
#  {'name': 'Trevor Ariza', 'salary': '6322320'},
#  {'name': 'Marcin Gortat', 'salary': '6322320'},
#  {'name': 'Kevin Durant', 'salary': '6053663'},
#  {'name': 'Andray Blatche', 'salary': '5900000'},
#  {'name': "Jermaine O'Neal", 'salary': '5765000'},
#  {'name': 'Al Harrington', 'salary': '5765000'},
#  {'name': 'Wesley Matthews', 'salary': '5765000'},
#  {'name': 'Drew Gooden', 'salary': '5760000'},
#  {'name': 'Kyle Lowry', 'salary': '5750000'},
#  {'name': 'Mike Bibby', 'salary': '5564767'},
#  {'name': 'Derrick Rose', 'salary': '5546160'},
#  {'name': 'Nenad Krstic', 'salary': '5543116'},
#  {'name': 'Jamaal Tinsley', 'salary': '5500000'},
#  {'name': 'Francisco Garcia', 'salary': '5500000'},
#  {'name': 'Sasha Vujacic', 'salary': '5475113'},
#  {'name': 'Al Horford', 'salary': '5444857'},
#  {'name': 'Blake Griffin', 'salary': '5357280'},
#  {'name': 'Mickael Pietrus', 'salary': '5300000'},
#  {'name': 'Luke Walton', 'salary': '5260000'},
#  {'name': 'Channing Frye', 'salary': '5200000'},
#  {'name': 'John Wall', 'salary': '5144280'},
#  {'name': 'Reggie Evans', 'salary': '5080000'},
#  {'name': 'Kyle Korver', 'salary': '5000000'},
#  {'name': 'Jason Maxiell', 'salary': '5000000'},
#  {'name': 'Mike Miller', 'salary': '5000000'},
#  {'name': 'Louis Williams', 'salary': '5000000'},
#  {'name': 'Amir Johnson', 'salary': '5000000'},
#  {'name': 'Linas Kleiza', 'salary': '4995000'},
#  {'name': 'Michael Beasley', 'salary': '4962240'},
#  {'name': 'Mike Conley', 'salary': '4913007'},
#  {'name': 'Antonio McDyess', 'salary': '4860000'},
#  {'name': 'Marcus Banks', 'salary': '4847586'},
#  {'name': 'Darius Songaila', 'salary': '4818000'},
#  {'name': 'Martell Webster', 'salary': '4800000'},
#  {'name': 'Hasheem Thabeet', 'salary': '4793280'},
#  {'name': 'Ronnie Brewer', 'salary': '4790000'},
#  {'name': 'Kendrick Perkins', 'salary': '4640208'},
#  {'name': 'Evan Turner', 'salary': '4602720'},
#  {'name': 'Jarrett Jack', 'salary': '4600000'},
#  {'name': 'Chris Andersen', 'salary': '4533300'},
#  {'name': 'OJ Mayo', 'salary': '4456200'},
#  {'name': 'Jeff Green', 'salary': '4455988'},
#  {'name': 'Charlie Bell', 'salary': '4447792'},
#  {'name': 'Brad Miller', 'salary': '4400000'},
#  {'name': 'Darko Milicic', 'salary': '4325000'},
#  {'name': 'James Harden', 'salary': '4304520'},
#  {'name': 'Matt Carroll', 'salary': '4300000'},
#  {'name': 'Zaza Pachulia', 'salary': '4251250'},
#  {'name': 'Randy Foye', 'salary': '4250000'},
#  {'name': 'Hakim Warrick', 'salary': '4250000'},
#  {'name': 'Nate Robinson', 'salary': '4200000'},
#  {'name': 'DeShawn Stevenson', 'salary': '4151786'},
#  {'name': 'Derrick Favors', 'salary': '4133280'},
#  {'name': 'Yi Jianlian', 'salary': '4050499'},
#  {'name': 'Russell Westbrook', 'salary': '4017720'},
#  {'name': 'Daniel Gibson', 'salary': '4015334'},
#  {'name': 'Anthony Morrow', 'salary': '4000000'},
#  {'name': 'Ryan Gomes', 'salary': '4000000'},
#  {'name': 'Steve Blake', 'salary': '4000000'},
#  {'name': 'Nikola Pekovic', 'salary': '4000000'},
#  {'name': 'Luke Ridnour', 'salary': '4000000'},
#  {'name': 'Ronny Turiaf', 'salary': '4000000'},
#  {'name': 'Brandon Bass', 'salary': '4000000'},
#  {'name': 'Willie Green', 'salary': '3976000'},
#  {'name': 'Ramon Sessions', 'salary': '3964320'},
#  {'name': 'Tyreke Evans', 'salary': '3880920'},
#  {'name': 'Jordan Farmar', 'salary': '3750000'},
#  {'name': 'Wesley Johnson', 'salary': '3726600'},
#  {'name': 'Corey Brewer', 'salary': '3703472'},
#  {'name': 'Derek Fisher', 'salary': '3700000'},
#  {'name': 'CJ Miles', 'salary': '3700000'},
#  {'name': 'Kevin Love', 'salary': '3638280'},
#  {'name': 'Timofey Mozgov', 'salary': '3567096'},
#  {'name': 'Shaun Livingston', 'salary': '3500000'},
#  {'name': 'Dorell Wright', 'salary': '3500000'},
#  {'name': 'Udonis Haslem', 'salary': '3500000'},
#  {'name': 'Carlos Delfino', 'salary': '3500000'},
#  {'name': 'Chris Duhon', 'salary': '3500000'},
#  {'name': 'Marc Gasol', 'salary': '3480000'},
#  {'name': 'Tiago Splitter', 'salary': '3400000'},
#  {'name': 'Brandan Wright', 'salary': '3398072'},
#  {'name': 'DeMarcus Cousins', 'salary': '3374640'},
#  {'name': 'Grant Hill', 'salary': '3324000'},
#  {'name': 'Danilo Gallinari', 'salary': '3304560'},
#  {'name': 'Glen Davis', 'salary': '3300000'},
#  {'name': 'Joel Anthony', 'salary': '3300000'},
#  {'name': 'Kelenna Azubuike', 'salary': '3300000'},
#  {'name': 'Johan Petro', 'salary': '3250000'},
#  {'name': 'Will Bynum', 'salary': '3250000'},
#  {'name': 'Thabo Sefolosha', 'salary': '3250000'},
#  {'name': 'Kris Humphries', 'salary': '3200000'},
#  {'name': 'Jonny Flynn', 'salary': '3192000'},
#  {'name': 'Joakim Noah', 'salary': '3128536'},
#  {'name': 'CJ Watson', 'salary': '3100000'},
#  {'name': 'Ekpe Udoh', 'salary': '3065040'},
#  {'name': 'Eric Gordon', 'salary': '3016680'},
#  {'name': 'Eduardo Najera', 'salary': '3000000'},
#  {'name': 'Chris Wilcox', 'salary': '3000000'},
#  {'name': 'Jamario Moon', 'salary': '3000000'},
#  {'name': 'Tony Allen', 'salary': '3000000'},
#  {'name': 'Carl Landry', 'salary': '3000000'},
#  {'name': 'Matt Bonner', 'salary': '3000000'},
#  {'name': 'Raja Bell', 'salary': '3000000'},
#  {'name': 'Josh Howard', 'salary': '3000000'},
#  {'name': 'Spencer Hawes', 'salary': '2974320'},
#  {'name': 'Stephen Curry', 'salary': '2913840'},
#  {'name': 'Thaddeus Young', 'salary': '2901241'},
#  {'name': 'Julian Wright', 'salary': '2858057'},
#  {'name': 'Anthony Parker', 'salary': '2855700'},
#  {'name': 'Al Thornton', 'salary': '2814196'},
#  {'name': 'Greg Monroe', 'salary': '2798040'},
#  {'name': 'Rodney Stuckey', 'salary': '2767126'},
#  {'name': 'Sebastian Telfair', 'salary': '2700000'},
#  {'name': 'Jordan Hill', 'salary': '2669520'},
#  {'name': 'Nick Young', 'salary': '2630503'},
#  {'name': 'Al-Farouq Aminu', 'salary': '2563320'},
#  {'name': 'DJ Augustin', 'salary': '2540400'},
#  {'name': 'Dahntay Jones', 'salary': '2500000'},
#  {'name': 'David Andersen', 'salary': '2500000'},
#  {'name': 'Maurice Evans', 'salary': '2500000'},
#  {'name': 'Marquis Daniels', 'salary': '2470000'},
#  {'name': 'DeMar DeRozan', 'salary': '2453880'},
#  {'name': 'Brook Lopez', 'salary': '2413320'},
#  {'name': 'Rasual Butler', 'salary': '2400000'},
#  {'name': 'Marco Belinelli', 'salary': '2380270'},
#  {'name': 'Gordon Hayward', 'salary': '2356320'},
#  {'name': 'Ryan Hollins', 'salary': '2333333'},
#  {'name': 'Brandon Jennings', 'salary': '2331120'},
#  {'name': 'Ersan Ilyasova', 'salary': '2320500'},
#  {'name': 'Craig Smith', 'salary': '2300000'},
#  {'name': 'Jerryd Bayless', 'salary': '2292600'},
#  {'name': 'Quentin Richardson', 'salary': '2265000'},
#  {'name': 'Paul George', 'salary': '2238360'},
#  {'name': 'Louis Amundson', 'salary': '2225000'},
#  {'name': 'Terrence Williams', 'salary': '2214480'},
#  {'name': 'Shannon Brown', 'salary': '2200000'},
#  {'name': 'Anthony Tolliver', 'salary': '2200000'},
#  {'name': 'Jason Smith', 'salary': '2187913'},
#  {'name': 'Jason Thompson', 'salary': '2178000'},
#  {'name': 'Daequan Cook', 'salary': '2169857'},
#  {'name': 'Jared Dudley', 'salary': '2151068'},
#  {'name': 'Wilson Chandler', 'salary': '2130482'},
#  {'name': 'Cole Aldrich', 'salary': '2126520'},
#  {'name': 'Gerald Henderson', 'salary': '2103840'},
#  {'name': 'Ben Wallace', 'salary': '2080000'},
#  {'name': 'Brandon Rush', 'salary': '2069049'},
#  {'name': 'Xavier Henry', 'salary': '2020200'},
#  {'name': 'Aaron Brooks', 'salary': '2016692'},
#  {'name': 'Keyon Dooling', 'salary': '2000000'},
#  {'name': 'Tyler Hansbrough', 'salary': '1998600'},
#  {'name': 'Chuck Hayes', 'salary': '1972500'},
#  {'name': 'Goran Dragic', 'salary': '1972000'},
#  {'name': 'Anthony Randolph', 'salary': '1965720'},
#  {'name': 'Arron Afflalo', 'salary': '1959577'},
#  {'name': 'Ed Davis', 'salary': '1919160'},
#  {'name': 'Earl Clark', 'salary': '1898760'},
#  {'name': 'Jason Williams', 'salary': '1877145'},
#  {'name': 'Robin Lopez', 'salary': '1867320'},
#  {'name': 'Patrick Patterson', 'salary': '1823280'},
#  {'name': 'Jose Juan Barea', 'salary': '1815000'},
#  {'name': 'Austin Daye', 'salary': '1803720'},
#  {'name': 'Marreese Speights', 'salary': '1773960'},
#  {'name': 'Matt Barnes', 'salary': '1765000'},
#  {'name': 'Larry Sanders', 'salary': '1731960'},
#  {'name': 'Omer Asik', 'salary': '1721000'},
#  {'name': 'James Johnson', 'salary': '1713600'},
#  {'name': 'Roy Hibbert', 'salary': '1685280'},
#  {'name': 'Renaldo Balkman', 'salary': '1675000'},
#  {'name': 'Luke Babbitt', 'salary': '1645440'},
#  {'name': 'Jrue Holiday', 'salary': '1627920'},
#  {'name': 'JaVale McGee', 'salary': '1601040'},
#  {'name': 'Keith Bogans', 'salary': '1600000'},
#  {'name': 'Hamed Haddadi', 'salary': '1600000'},
#  {'name': 'Kevin Seraphin', 'salary': '1563120'},
#  {'name': 'Ty Lawson', 'salary': '1546560'},
#  {'name': 'JJ Hickson', 'salary': '1528920'},
#  {'name': 'Solomon Jones', 'salary': '1500000'},
#  {'name': 'Eric Bledsoe', 'salary': '1485000'},
#  {'name': 'Jeff Teague', 'salary': '1476840'},
#  {'name': 'Alexis Ajinca', 'salary': '1467840'},
#  {'name': 'Avery Bradley', 'salary': '1418160'},
#  {'name': 'Eric Maynor', 'salary': '1417800'},
#  {'name': 'Courtney Lee', 'salary': '1409040'},
#  {'name': 'Ryan Anderson', 'salary': '1409040'},
#  {'name': 'Roger Mason', 'salary': '1400000'},
#  {'name': 'Ronnie Price', 'salary': '1380000'},
#  {'name': 'James Anderson', 'salary': '1361400'},
#  {'name': 'Darren Collison', 'salary': '1361040'},
#  {'name': 'Kosta Koufos', 'salary': '1352640'},
#  {'name': 'Jason Collins', 'salary': '1352181'},
#  {'name': "Shaquille O'Neal", 'salary': '1352181'},
#  {'name': 'Kurt Thomas', 'salary': '1352181'},
#  {'name': 'Brian Cardinal', 'salary': '1352181'},
#  {'name': 'Tracy McGrady', 'salary': '1352181'},
#  {'name': 'Theo Ratliff', 'salary': '1352181'},
#  {'name': 'Joe Smith', 'salary': '1352181'},
#  {'name': 'Zydrunas Ilgauskas', 'salary': '1352181'},
#  {'name': 'Juwan Howard', 'salary': '1352181'},
#  {'name': 'Eddie House', 'salary': '1352181'},
#  {'name': 'Earl Boykins', 'salary': '1352181'},
#  {'name': 'Anthony Carter', 'salary': '1352181'},
#  {'name': 'Tony Battie', 'salary': '1352181'},
#  {'name': 'Craig Brackins', 'salary': '1306920'},
#  {'name': 'Sean Marks', 'salary': '1264687'},
#  {'name': 'Elliot Williams', 'salary': '1254720'},
#  {'name': 'Omri Casspi', 'salary': '1254480'},
#  {'name': 'Rudy Fernandez', 'salary': '1246680'},
#  {'name': 'Kwame Brown', 'salary': '1229255'},
#  {'name': 'Brian Scalabrine', 'salary': '1229255'},
#  {'name': 'Jamaal Magloire', 'salary': '1229255'},
#  {'name': 'Malik Allen', 'salary': '1229255'},
#  {'name': 'Earl Watson', 'salary': '1229255'},
#  {'name': 'Etan Thomas', 'salary': '1223166'},
#  {'name': 'Melvin Ely', 'salary': '1223166'},
#  {'name': 'Carlos Arroyo', 'salary': '1223166'},
#  {'name': 'Trevor Booker', 'salary': '1204560'},
#  {'name': 'Serge Ibaka', 'salary': '1204200'},
#  {'name': 'BJ Mullens', 'salary': '1204200'},
#  {'name': 'Royal Ivey', 'salary': '1200000'},
#  {'name': 'Nicolas Batum', 'salary': '1196760'},
#  {'name': 'George Hill', 'salary': '1157160'},
#  {'name': 'Damion James', 'salary': '1156320'},
#  {'name': 'Rodrigue Beaubois', 'salary': '1156080'},
#  {'name': 'Quinton Ross', 'salary': '1146337'},
#  {'name': 'Brian Cook', 'salary': '1146337'},
#  {'name': 'Francisco Elson', 'salary': '1146337'},
#  {'name': 'Erick Dampier', 'salary': '1129469'},
#  {'name': 'Darrell Arthur', 'salary': '1123680'},
#  {'name': 'Taj Gibson', 'salary': '1117680'},
#  {'name': 'Donte Greene', 'salary': '1116840'},
#  {'name': 'Dominique Jones', 'salary': '1110120'},
#  {'name': 'DJ White', 'salary': '1108680'},
#  {'name': 'Kyrylo Fesenko', 'salary': '1087500'},
#  {'name': 'DeMarre Carroll', 'salary': '1085400'},
#  {'name': 'Wayne Ellington', 'salary': '1078800'},
#  {'name': 'Quincy Pondexter', 'salary': '1073280'},
#  {'name': 'Toney Douglas', 'salary': '1071000'},
#  {'name': 'Josh Powell', 'salary': '1069609'},
#  {'name': 'Delonte West', 'salary': '1069509'},
#  {'name': 'James Jones', 'salary': '1069509'},
#  {'name': 'Didier Ilunga-Mbenga', 'salary': '1069509'},
#  {'name': 'Jordan Crawford', 'salary': '1042320'},
#  {'name': 'Greivis Vasquez', 'salary': '1035960'},
#  {'name': 'Aaron Gray', 'salary': '1028840'},
#  {'name': 'Daniel Orton', 'salary': '1028400'},
#  {'name': 'Christian Eyenga', 'salary': '1020960'},
#  {'name': 'Lazar Hayward', 'salary': '1020960'},
#  {'name': 'Jon Brockman', 'salary': '1000000'},
#  {'name': 'Hilton Armstrong', 'salary': '992680'},
#  {'name': 'Stephen Graham', 'salary': '992680'},
#  {'name': 'Joey Graham', 'salary': '992680'},
#  {'name': 'Fabricio Oberto', 'salary': '992680'},
#  {'name': 'Luther Head', 'salary': '992680'},
#  {'name': 'Antoine Wright', 'salary': '992680'},
#  {'name': 'Patrick Mills', 'salary': '937195'},
#  {'name': 'DeJuan Blair', 'salary': '918000'},
#  {'name': 'Von Wafer', 'salary': '915852'},
#  {'name': 'Leon Powe', 'salary': '915852'},
#  {'name': 'Shelden Williams', 'salary': '915852'},
#  {'name': 'Sam Young', 'salary': '886000'},
#  {'name': 'Shawne Williams', 'salary': '885210'},
#  {'name': 'Josh McRoberts', 'salary': '885120'},
#  {'name': 'Dominic McGuire', 'salary': '884120'},
#  {'name': 'Chris Quinn', 'salary': '861978'},
#  {'name': 'Acie Law', 'salary': '859087'},
#  {'name': 'DeAndre Jordan', 'salary': '854389'},
#  {'name': 'Mario Chalmers', 'salary': '854389'},
#  {'name': 'Luc Mbah a Moute', 'salary': '854389'},
#  {'name': 'Chris Douglas-Roberts', 'salary': '854389'},
#  {'name': 'Henry Walker', 'salary': '854389'},
#  {'name': 'Darnell Jackson', 'salary': '854389'},
#  {'name': 'Sonny Weems', 'salary': '854389'},
#  {'name': 'Joey Dorsey', 'salary': '854389'},
#  {'name': 'Cartier Martin', 'salary': '854389'},
#  {'name': 'Chase Budinger', 'salary': '780871'},
#  {'name': 'Jermaine Taylor', 'salary': '780871'},
#  {'name': 'Solomon Alabi', 'salary': '770000'},
#  {'name': 'Ian Mahinmi', 'salary': '762196'},
#  {'name': 'Dante Cunningham', 'salary': '762195'},
#  {'name': 'Derrick Brown', 'salary': '762195'},
#  {'name': 'DaJuan Summers', 'salary': '762195'},
#  {'name': 'Jonas Jerebko', 'salary': '762195'},
#  {'name': 'Reggie Williams', 'salary': '762195'},
#  {'name': 'AJ Price', 'salary': '762195'},
#  {'name': 'Jodie Meeks', 'salary': '762195'},
#  {'name': 'Marcus Thornton', 'salary': '762195'},
#  {'name': 'Lance Stephenson', 'salary': '750000'},
#  {'name': 'Damien Wilkins', 'salary': '748656'},
#  {'name': 'Steve Novak', 'salary': '734945'},
#  {'name': 'Hassan Whiteside', 'salary': '730437'},
#  {'name': 'Alonzo Gee', 'salary': '681492'},
#  {'name': 'Rodney Carney', 'salary': '651872'},
#  {'name': 'Jarron Collins', 'salary': '643551'},
#  {'name': 'Ike Diogu', 'salary': '608772'},
#  {'name': 'Andy Rautins', 'salary': '600000'},
#  {'name': 'Gary Neal', 'salary': '525000'},
#  {'name': 'Samardo Samuels', 'salary': '500000'},
#  {'name': 'Willie Warren', 'salary': '500000'},
#  {'name': 'Gani Lawal', 'salary': '473640'},
#  {'name': 'Garret Siler', 'salary': '473640'},
#  {'name': 'Pape Sy', 'salary': '473604'},
#  {'name': 'Ben Uzoh', 'salary': '473604'},
#  {'name': 'Sherron Collins', 'salary': '473604'},
#  {'name': 'Semih Erden', 'salary': '473604'},
#  {'name': 'Luke Harangody', 'salary': '473604'},
#  {'name': 'Manny Harris', 'salary': '473604'},
#  {'name': 'Gary Forbes', 'salary': '473604'},
#  {'name': 'Terrico White', 'salary': '473604'},
#  {'name': 'Jeremy Lin', 'salary': '473604'},
#  {'name': 'Devin Ebanks', 'salary': '473604'},
#  {'name': 'Derrick Caracter', 'salary': '473604'},
#  {'name': 'Ishmael Smith', 'salary': '473604'},
#  {'name': 'Patrick Beverley', 'salary': '473604'},
#  {'name': 'Dexter Pittman', 'salary': '473604'},
#  {'name': "Da'Sean Butler", 'salary': '473604'},
#  {'name': 'Landry Fields', 'salary': '473604'},
#  {'name': 'Armon Johnson', 'salary': '473604'},
#  {'name': 'Pooh Jeter', 'salary': '473604'},
#  {'name': 'Jeremy Evans', 'salary': '473604'},
#  {'name': "Hamady N'Diaye", 'salary': '473604'},
#  {'name': 'Pops Mensah-Bonsu', 'salary': '364461'},
#  {'name': 'Jeff Adrien', 'salary': '342666'},
#  {'name': 'Sundiata Gaines', 'salary': '327296'},
#  {'name': 'Jawad Williams', 'salary': '321652'},
#  {'name': 'Brian Skinner', 'salary': '270436'},
#  {'name': 'Ime Udoka', 'salary': '264232'},
#  {'name': 'Zabian Dowdell', 'salary': '242374'},
#  {'name': 'Jerry Stackhouse', 'salary': '222712'},
#  {'name': 'John Lucas', 'salary': '208264'},
#  {'name': 'Aleksandar Pavlovic', 'salary': '202295'},
#  {'name': 'Lester Hudson', 'salary': '192791'},
#  {'name': 'Earl Barron', 'salary': '188558'},
#  {'name': 'Garrett Temple', 'salary': '170373'},
#  {'name': 'Chris Johnson', 'salary': '164368'},
#  {'name': 'Darington Hobson', 'salary': '103078'},
#  {'name': 'Danny Green', 'salary': '94154'},
#  {'name': 'Joe Alexander', 'salary': '90465'},
#  {'name': 'Trey Johnson', 'salary': '89670'},
#  {'name': 'Mustafa Shakur', 'salary': '89670'},
#  {'name': 'Maurice Ager', 'salary': '83305'},
#  {'name': 'Bobby Simmons', 'salary': '71951'},
#  {'name': 'Matt Janning', 'salary': '58504'},
#  {'name': 'Ronald Dupree', 'salary': '58393'},
#  {'name': 'Larry Owens', 'salary': '55718'}]

# %% [markdown]
# ### Import NBA Historical Statsitics Dataset

# %%
statsdf = pd.read_csv('./Data/Seasons_Stats.csv')

# %%
statsdf.columns #It is disappointing that per game stats were not included but these are easily calculated and can be added afterward
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
statsdf = statsdf[statsdf['Year']>2007] #initially include only 10 years of data

# %%
statsdf.drop(columns = ['Unnamed: 0', 'blanl', 'blank2'], axis = 1, inplace = True)

# %%
statsdf.reset_index(drop = True, inplace = True)

# %%
statsdf.columns = statsdf.columns.str.lower()

# %%
statsdf.head()
# Out:
#      year               player pos   age   tm     g   gs     mp   per    ts%  \
# 0  2008.0  Shareef Abdur-Rahim  PF  31.0  SAC   6.0  0.0   51.0   5.5  0.317
# 1  2008.0        Arron Afflalo  SG  22.0  DET  75.0  9.0  970.0  10.2  0.494
# 2  2008.0         Maurice Ager  SG  23.0  TOT  26.0  3.0  165.0   1.8  0.363
# 3  2008.0         Maurice Ager  SG  23.0  DAL  12.0  3.0   77.0  -4.4  0.253
# 4  2008.0         Maurice Ager  SG  23.0  NJN  14.0  0.0   88.0   7.1  0.443
#
#    ...    ft%   orb    drb    trb   ast   stl  blk   tov    pf    pts
# 0  ...  1.000   6.0    4.0   10.0   4.0   1.0  0.0   1.0   9.0   10.0
# 1  ...  0.782  36.0  101.0  137.0  52.0  31.0  8.0  34.0  83.0  276.0
# 2  ...  0.500   4.0    9.0   13.0   8.0   0.0  1.0   6.0  17.0   51.0
# 3  ...  0.833   1.0    3.0    4.0   4.0   0.0  1.0   3.0  11.0   15.0
# 4  ...  0.167   3.0    6.0    9.0   4.0   0.0  0.0   3.0   6.0   36.0
#
# [5 rows x 50 columns]

# %%
#Year and Age dtype conversion
statsdf['year'] = statsdf['year'].astype(int)
statsdf['age'] = statsdf['age'].astype(int)

# %% [markdown]
# ### Set Salary into Dataframe

# %%
salary08df = pd.DataFrame(salary2008)
salary09df = pd.DataFrame(salary2009)
salary10df = pd.DataFrame(salary2010)
salary11df = pd.DataFrame(salary2011)
salary12df = pd.DataFrame(salary2012)
salary13df = pd.DataFrame(salary2013)
salary14df = pd.DataFrame(salary2014)
salary15df = pd.DataFrame(salary2015)
salary16df = pd.DataFrame(salary2016)
salary17df = pd.DataFrame(salary2017)

# %%
salary08df
# Out:
#                  name    salary
# 0       Kevin Garnett  23750000
# 1      Michael Finley  21696750
# 2    Shaquille O'Neal  20000000
# 3          Jason Kidd  19728000
# 4     Jermaine O'Neal  19728000
# ..                ...       ...
# 464    Thomas Gardner    101451
# 465      Orien Greene     77061
# 466    Guillermo Diaz     56065
# 467    Stephane Lasme     48056
# 468   DerMarr Johnson     42203
#
# [469 rows x 2 columns]

# %%
#function to remove html tags and convert contract amount to float. renamed name column to enable merge with statsdf
#tags and symbols subsequently removed at data acquisition so those sections are now redundant

def cleanup(df):
#     df['name'] = df['name'].str.replace('\\n','')
#     df['name'] = df['name'].str.replace('\\t','')
#     df['salary'] = df['salary'].str.replace('\\n','')    
#     df['salary'] = df['salary'].str.replace('\\t','')
#     df['salary'] = df['salary'].str.replace('$','')
#     df['salary'] = df['salary'].str.replace(',','').astype(float)
    df.rename(columns={"name": "player"}, inplace = True)
    return df

# %%
salary08df = cleanup(salary08df)
salary09df = cleanup(salary09df)
salary10df = cleanup(salary10df)
salary11df = cleanup(salary11df)
salary12df = cleanup(salary12df)
salary13df = cleanup(salary13df)
salary14df = cleanup(salary14df)
salary15df = cleanup(salary15df)
salary16df = cleanup(salary16df)
salary17df = cleanup(salary17df)

# %% [markdown]
# ### Merge Stats DF with Salary DF

# %%
stats2008 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2008)], right = salary08df, on = 'player')
stats2009 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2009)], right = salary09df, on = 'player')
stats2010 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2010)], right = salary10df, on = 'player')
stats2011 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2011)], right = salary11df, on = 'player')
stats2012 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2012)], right = salary12df, on = 'player')
stats2013 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2013)], right = salary13df, on = 'player')
stats2014 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2014)], right = salary14df, on = 'player')
stats2015 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2015)], right = salary15df, on = 'player')
stats2016 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2016)], right = salary16df, on = 'player')
stats2017 = pd.merge(left = statsdf.loc[(statsdf['year'] == 2017)], right = salary17df, on = 'player')

# %%
print (stats2008.shape)
print (stats2009.shape)
print (stats2010.shape)
print (stats2011.shape)
print (stats2012.shape)
print (stats2013.shape)
print (stats2014.shape)
print (stats2015.shape)
print (stats2016.shape)
print (stats2017.shape)
# Out:
# (562, 51)
# (542, 51)
# (540, 51)
# (574, 51)
# (494, 51)
# (538, 51)
# (561, 51)
# (588, 51)
# (534, 51)
# (551, 51)

# %% [markdown]
# ### Remove Duplicate Rows for Traded Players

# %%
#function to remove duplicate rows for traded players
def tradedplayerdrop(df):
    traded = [df['player'][i] for i in range(len(df['player'])) if df['tm'][i] == 'TOT']
    for i in df.index:
        if df['player'][i] in traded:
            if df['tm'][i] != 'TOT':
                df.loc[i,'tm'] = 'drop'

    df = df[df['tm'] != 'drop']
    return df

# %%
stats2008 = tradedplayerdrop(stats2008)
stats2009 = tradedplayerdrop(stats2009)
stats2010 = tradedplayerdrop(stats2010)
stats2011 = tradedplayerdrop(stats2011)
stats2012 = tradedplayerdrop(stats2012)
stats2013 = tradedplayerdrop(stats2013)
stats2014 = tradedplayerdrop(stats2014)
stats2015 = tradedplayerdrop(stats2015)
stats2016 = tradedplayerdrop(stats2016)
stats2017 = tradedplayerdrop(stats2017)

# %%
stats2015
# Out:
#      year          player pos  age   tm     g    gs      mp   per    ts%  ...  \
# 0    2015      Quincy Acy  PF   24  NYK  68.0  22.0  1287.0  11.9  0.533  ...
# 1    2015    Jordan Adams  SG   20  MEM  30.0   0.0   248.0  12.8  0.489  ...
# 2    2015    Steven Adams   C   21  OKC  70.0  67.0  1771.0  14.1  0.549  ...
# 3    2015     Jeff Adrien  PF   28  MIN  17.0   0.0   215.0  14.2  0.494  ...
# 4    2015   Arron Afflalo  SG   29  TOT  78.0  72.0  2502.0  10.7  0.533  ...
# ..    ...             ...  ..  ...  ...   ...   ...     ...   ...    ...  ...
# 581  2015     James Young  SG   19  BOS  31.0   0.0   332.0   8.5  0.457  ...
# 582  2015      Nick Young  SG   29  LAL  42.0   0.0  1000.0  14.2  0.520  ...
# 583  2015  Thaddeus Young  PF   26  TOT  76.0  68.0  2434.0  15.7  0.507  ...
# 586  2015     Cody Zeller   C   22  CHO  62.0  45.0  1487.0  14.1  0.530  ...
# 587  2015    Tyler Zeller   C   25  BOS  82.0  59.0  1731.0  18.9  0.594  ...
#
#        orb    drb    trb    ast    stl   blk    tov     pf     pts   salary
# 0     79.0  222.0  301.0   68.0   27.0  22.0   60.0  147.0   398.0   915243
# 1      9.0   19.0   28.0   16.0   16.0   7.0   14.0   24.0    94.0  1344120
# 2    199.0  324.0  523.0   66.0   38.0  86.0   99.0  222.0   537.0  2184960
# 3     23.0   54.0   77.0   15.0    4.0   9.0    9.0   30.0    60.0  1217698
# 4     27.0  220.0  247.0  129.0   41.0   7.0  116.0  167.0  1035.0  7562500
# ..     ...    ...    ...    ...    ...   ...    ...    ...     ...      ...
# 581    9.0   33.0   42.0   13.0    8.0   2.0    5.0   22.0   105.0  1674480
# 582   17.0   79.0   96.0   41.0   23.0  11.0   44.0   83.0   563.0  4994420
# 583  127.0  284.0  411.0  173.0  124.0  25.0  117.0  171.0  1071.0  9160870
# 586   97.0  265.0  362.0  100.0   34.0  49.0   62.0  156.0   472.0  4030560
# 587  146.0  319.0  465.0  113.0   18.0  52.0   76.0  205.0   833.0  1703760
#
# [455 rows x 51 columns]

# %%
statsdf = pd.concat([stats2008, stats2009], axis = 0)
statsdf = pd.concat([statsdf, stats2010], axis = 0)
statsdf = pd.concat([statsdf, stats2011], axis = 0)
statsdf = pd.concat([statsdf, stats2012], axis = 0)
statsdf = pd.concat([statsdf, stats2013], axis = 0)
statsdf = pd.concat([statsdf, stats2014], axis = 0)
statsdf = pd.concat([statsdf, stats2015], axis = 0)
statsdf = pd.concat([statsdf, stats2016], axis = 0)
statsdf = pd.concat([statsdf, stats2017], axis = 0)

# %%
statsdf.reset_index(drop = True, inplace = True)

# %%
statsdf
# Out:
#       year               player pos  age   tm     g    gs      mp   per  \
# 0     2008  Shareef Abdur-Rahim  PF   31  SAC   6.0   0.0    51.0   5.5
# 1     2008        Arron Afflalo  SG   22  DET  75.0   9.0   970.0  10.2
# 2     2008         Maurice Ager  SG   23  TOT  26.0   3.0   165.0   1.8
# 3     2008    LaMarcus Aldridge  PF   22  POR  76.0  76.0  2649.0  18.5
# 4     2008          Malik Allen  PF   29  TOT  73.0  16.0  1096.0   9.8
# ...    ...                  ...  ..  ...  ...   ...   ...     ...   ...
# 4313  2017          Cody Zeller  PF   24  CHO  62.0  58.0  1725.0  16.7
# 4314  2017         Tyler Zeller   C   27  BOS  51.0   5.0   525.0  13.0
# 4315  2017    Stephen Zimmerman   C   20  ORL  19.0   0.0   108.0   7.3
# 4316  2017          Paul Zipser  SF   22  CHI  44.0  18.0   843.0   6.9
# 4317  2017          Ivica Zubac   C   19  LAL  38.0  11.0   609.0  17.0
#
#         ts%  ...    orb    drb    trb    ast   stl   blk    tov     pf  \
# 0     0.317  ...    6.0    4.0   10.0    4.0   1.0   0.0    1.0    9.0
# 1     0.494  ...   36.0  101.0  137.0   52.0  31.0   8.0   34.0   83.0
# 2     0.363  ...    4.0    9.0   13.0    8.0   0.0   1.0    6.0   17.0
# 3     0.523  ...  220.0  358.0  578.0  122.0  55.0  94.0  126.0  240.0
# 4     0.500  ...   66.0  130.0  196.0   44.0  19.0  31.0   45.0  149.0
# ...     ...  ...    ...    ...    ...    ...   ...   ...    ...    ...
# 4313  0.604  ...  135.0  270.0  405.0   99.0  62.0  58.0   65.0  189.0
# 4314  0.508  ...   43.0   81.0  124.0   42.0   7.0  21.0   20.0   61.0
# 4315  0.346  ...   11.0   24.0   35.0    4.0   2.0   5.0    3.0   17.0
# 4316  0.503  ...   15.0  110.0  125.0   36.0  15.0  16.0   40.0   78.0
# 4317  0.547  ...   41.0  118.0  159.0   30.0  14.0  33.0   30.0   66.0
#
#          pts   salary
# 0       10.0  5800000
# 1      276.0   944520
# 2       51.0   974400
# 3     1350.0  4329360
# 4      338.0   998398
# ...      ...      ...
# 4313   639.0  5318313
# 4314   178.0  8000000
# 4315    23.0   950000
# 4316   240.0   750000
# 4317   284.0  1034865
#
# [4318 rows x 51 columns]

# %% [markdown]
# ### Export Merged File

# %%
#export the merged stat and salary df so we don't need to scrape again
statsdf.to_csv('./Data/stats_merged.csv', sep = ',', index=False)

# %% [markdown]
# ### Additional Considerations

# %% [markdown]
# Considered adding player details such as height, weight, etc. but discovered that some players with the same name played at the same time. Need to verify if this affects dataset in use (2008-2017 seasons)

# %%
statsdf = pd.read_csv('./Data/stats_merged.csv')

# %%
players = pd.read_csv('./Data/Players.csv')
playerdata = pd.read_csv('./Data/player_data.csv')

# %%
players
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# 4              University of Kentucky  1927.0     Hardinsburg
# ...                               ...     ...             ...
# 3917  South Carolina State University  1969.0        Columbia
# 3918               Gonzaga University  1992.0        Portland
# 3919  University of Nevada, Las Vegas  1996.0  Hendersonville
# 3920                              NaN  1994.0      Heidelberg
# 3921                              NaN  1997.0          Mostar
#
#                  birth_state
# 0                        NaN
# 1                    Indiana
# 2                        NaN
# 3                        NaN
# 4                   Kentucky
# ...                      ...
# 3917          South Carolina
# 3918                  Oregon
# 3919               Tennessee
# 3920                 Germany
# 3921  Bosnia and Herzegovina
#
# [3922 rows x 8 columns]

# %%
duplicatedrowsDF = players[players['Player'].duplicated()]

# %%
duplicatedrowsDF
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Player, height, weight, collage, born, birth_city, birth_state]
# Index: []

# %%
playerdata
# Out:
#                      name  year_start  year_end position height  weight  \
# 0          Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1         Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2     Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3      Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4       Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
# ...                   ...         ...       ...      ...    ...     ...
# 4545           Ante Zizic        2018      2018      F-C   6-11   250.0
# 4546             Jim Zoet        1983      1983        C    7-1   240.0
# 4547            Bill Zopf        1971      1971        G    6-1   170.0
# 4548          Ivica Zubac        2017      2018        C    7-1   265.0
# 4549           Matt Zunic        1949      1949      G-F    6-3   195.0
#
#              birth_date                                college
# 0         June 24, 1968                        Duke University
# 1         April 7, 1946                  Iowa State University
# 2        April 16, 1947  University of California, Los Angeles
# 3         March 9, 1969             Louisiana State University
# 4      November 3, 1974              San Jose State University
# ...                 ...                                    ...
# 4545    January 4, 1997                                    NaN
# 4546  December 20, 1953                  Kent State University
# 4547       June 7, 1948                    Duquesne University
# 4548     March 18, 1997                                    NaN
# 4549  December 19, 1919           George Washington University
#
# [4550 rows x 8 columns]

# %%
duplicatedrowsDF = playerdata[playerdata['name'].duplicated()]

# %%
duplicatedrowsDF
# Out:
#                   name  year_start  year_end position height  weight  \
# 80        Dan Anderson        1975      1976        G    6-2   185.0
# 424       Bill Bradley        1968      1977      F-G    6-5   205.0
# 488          Dee Brown        2007      2009        G    6-0   185.0
# 514        Roger Brown        1973      1980        C   6-11   225.0
# 925         Mark Davis        1996      2000      G-F    6-7   210.0
# 929         Mike Davis        1983      1983        F   6-10   230.0
# 1055        Larry Drew        2015      2015        G    6-2   180.0
# 1069         Bob Duffy        1963      1965        G    6-3   185.0
# 1080     Mike Dunleavy        2003      2017      F-G    6-9   230.0
# 1191     Patrick Ewing        2011      2011        F    6-8   235.0
# 1563       Matt Guokas        1967      1976      G-F    6-5   175.0
# 1626      Tim Hardaway        2014      2018        G    6-6   205.0
# 1715  Cedric Henderson        1998      2002        F    6-7   215.0
# 1718  Gerald Henderson        2010      2017        G    6-5   215.0
# 1923      Luke Jackson        2005      2008        F    6-7   215.0
# 1938      Tony Jackson        1981      1981        G    6-0   170.0
# 1954        Mike James        2018      2018        G    6-1   189.0
# 2000     Chris Johnson        2013      2016      F-G    6-6   206.0
# 2011     Eddie Johnson        1982      1999      F-G    6-7   215.0
# 2016    George Johnson        1973      1986      C-F   6-11   205.0
# 2017    George Johnson        1979      1986      F-C    6-7   210.0
# 2027       Ken Johnson        2003      2003      F-C   6-11   240.0
# 2030     Larry Johnson        1992      2001        F    6-6   250.0
# 2063       Bobby Jones        2007      2008        F    6-7   215.0
# 2066     Charles Jones        1985      1989        F    6-8   215.0
# 2067     Charles Jones        1999      2000        G    6-3   180.0
# 2094        Mark Jones        2005      2005        G    6-6   215.0
# 2359         David Lee        2006      2017        F    6-9   245.0
# 2393     Freddie Lewis        1967      1977        G    6-0   175.0
# 2787     Tony Mitchell        2014      2014        F    6-8   235.0
# 2910       Larry Nance        2016      2018        F    6-9   230.0
# 3137        Jim Paxson        1980      1990      G-F    6-6   200.0
# 3146       Gary Payton        2017      2018        G    6-3   190.0
# 3369         Glen Rice        2014      2015        G    6-6   206.0
# 3430    Glenn Robinson        2015      2017      G-F    6-6   222.0
# 3522    Walker Russell        2012      2012        G    6-0   170.0
# 3733     Charles Smith        1990      1996        G    6-1   160.0
# 3734     Charles Smith        1998      2006        G    6-4   194.0
# 3736       Chris Smith        2014      2014        G    6-2   200.0
# 3743         Don Smith        1975      1975        G    6-0   160.0
# 3750        Greg Smith        2012      2016        C   6-10   250.0
# 3767     Michael Smith        1995      2001        F    6-8   230.0
# 3778         Sam Smith        1979      1980        G    6-4   200.0
# 4088       Jack Turner        1962      1962      G-F    6-5   200.0
# 4138      David Vaughn        1996      1999        F    6-9   240.0
# 4393   Marcus Williams        2008      2009        F    6-7   205.0
# 4405   Reggie Williams        2010      2017        F    6-6   205.0
# 4410      Sam Williams        1982      1985        F    6-8   210.0
# 4431      Bobby Wilson        1975      1978        G    6-3   175.0
# 4496      Chris Wright        2013      2013        G    6-1   210.0
#
#               birth_date                                     college
# 80       January 1, 1951           University of Southern California
# 424        July 28, 1943                        Princeton University
# 488      August 17, 1984  University of Illinois at Urbana-Champaign
# 514    February 23, 1950                        University of Kansas
# 925       April 26, 1973                       Texas Tech University
# 929       August 2, 1956                      University of Maryland
# 1055       March 5, 1990       University of California, Los Angeles
# 1069  September 26, 1940                          Colgate University
# 1080  September 15, 1980                             Duke University
# 1191        May 20, 1984                       Georgetown University
# 1563   February 25, 1944                   Saint Joseph's University
# 1626      March 16, 1992                      University of Michigan
# 1715      March 11, 1975                       University of Memphis
# 1718    December 9, 1987                             Duke University
# 1923    November 6, 1981                        University of Oregon
# 1938    January 17, 1958                    Florida State University
# 1954     August 18, 1990                            Lamar University
# 2000      April 29, 1990                        University of Dayton
# 2011         May 1, 1959  University of Illinois at Urbana-Champaign
# 2016   December 18, 1948                          Dillard University
# 2017    December 8, 1956                       St. John's University
# 2027    February 1, 1978                       Ohio State University
# 2030      March 14, 1969             University of Nevada, Las Vegas
# 2063     January 9, 1984                    University of Washington
# 2066    January 12, 1962                    University of Louisville
# 2067       July 17, 1975                      Long Island University
# 2094        May 25, 1975               University of Central Florida
# 2359      April 29, 1983                       University of Florida
# 2393        July 1, 1943                    Arizona State University
# 2787       April 7, 1992                   University of North Texas
# 2910     January 1, 1993                       University of Wyoming
# 3137        July 9, 1957                        University of Dayton
# 3146    December 1, 1992                     Oregon State University
# 3369     January 1, 1991             Georgia Institute of Technology
# 3430     January 8, 1994                      University of Michigan
# 3522     October 6, 1982               Jacksonville State University
# 3733   November 29, 1967                       Georgetown University
# 3734     August 22, 1975                    University of New Mexico
# 3736    October 13, 1987                    University of Louisville
# 3743    October 10, 1951                        University of Dayton
# 3750     January 8, 1991         California State University, Fresno
# 3767      March 28, 1972                          Providence College
# 3778     January 8, 1955             University of Nevada, Las Vegas
# 4088        June 5, 1939                    University of Louisville
# 4138      March 23, 1973                       University of Memphis
# 4393   November 18, 1986                       University of Arizona
# 4405  September 14, 1986                 Virginia Military Institute
# 4410       March 7, 1959                    Arizona State University
# 4431    January 15, 1951                    Wichita State University
# 4496    November 4, 1989                       Georgetown University

# %%
playerdata = playerdata[playerdata['year_end'] > 2005]
playerdata = playerdata[playerdata['year_start'] < 2018]

# %%
duplicatedrowsDF = playerdata[playerdata['name'].duplicated()]
duplicatedrowsDF
# Out:
#                  name  year_start  year_end position height  weight  \
# 2000    Chris Johnson        2013      2016      F-G    6-6   206.0
# 2787    Tony Mitchell        2014      2014        F    6-8   235.0
# 3146      Gary Payton        2017      2018        G    6-3   190.0
# 4393  Marcus Williams        2008      2009        F    6-7   205.0
# 4496     Chris Wright        2013      2013        G    6-1   210.0
#
#              birth_date                    college
# 2000     April 29, 1990       University of Dayton
# 2787      April 7, 1992  University of North Texas
# 3146   December 1, 1992    Oregon State University
# 4393  November 18, 1986      University of Arizona
# 4496   November 4, 1989      Georgetown University

# %%
playerdata[playerdata['name'] == 'Chris Johnson']
# Out:
#                name  year_start  year_end position height  weight  \
# 1999  Chris Johnson        2011      2013        C   6-11   210.0
# 2000  Chris Johnson        2013      2016      F-G    6-6   206.0
#
#           birth_date                     college
# 1999   July 15, 1985  Louisiana State University
# 2000  April 29, 1990        University of Dayton

# %%
playerdata[playerdata['name'] == 'Tony Mitchell']
# Out:
#                name  year_start  year_end position height  weight  \
# 2786  Tony Mitchell        2014      2014        F    6-6   216.0
# 2787  Tony Mitchell        2014      2014        F    6-8   235.0
#
#           birth_date                    college
# 2786  August 7, 1989      University of Alabama
# 2787   April 7, 1992  University of North Texas

# %%
playerdata[playerdata['name'] == 'Gary Payton']
# Out:
#              name  year_start  year_end position height  weight  \
# 3145  Gary Payton        1991      2007        G    6-4   180.0
# 3146  Gary Payton        2017      2018        G    6-3   190.0
#
#             birth_date                  college
# 3145     July 23, 1968  Oregon State University
# 3146  December 1, 1992  Oregon State University

# %%
playerdata[playerdata['name'] == 'Marcus Williams']
# Out:
#                  name  year_start  year_end position height  weight  \
# 4392  Marcus Williams        2007      2010        G    6-3   205.0
# 4393  Marcus Williams        2008      2009        F    6-7   205.0
#
#              birth_date                    college
# 4392   December 3, 1985  University of Connecticut
# 4393  November 18, 1986      University of Arizona

# %%
playerdata[playerdata['name'] == 'Chris Wright']
# Out:
#               name  year_start  year_end position height  weight  \
# 4495  Chris Wright        2012      2014        F    6-8   226.0
# 4496  Chris Wright        2013      2013        G    6-1   210.0
#
#               birth_date                college
# 4495  September 30, 1988   University of Dayton
# 4496    November 4, 1989  Georgetown University

# %% [markdown]
# Reviewing both supplemental files shows that the 'players.csv' is less useful compared to the 'playerdata.csv' file. The 'playerdata' file contains nearly all of the same info but with improved detail.

# %%
playerdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1284 entries, 5 to 4548
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1284 non-null   object
#  1   year_start  1284 non-null   int64
#  2   year_end    1284 non-null   int64
#  3   position    1284 non-null   object
#  4   height      1284 non-null   object
#  5   weight      1284 non-null   float64
#  6   birth_date  1284 non-null   object
#  7   college     1077 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 90.3+ KB

# %%
playerdata.reset_index(drop = True, inplace = True)

# %%
playerdata.loc[:,'height'] = [(int(playerdata['height'][i][0])*12 + int(playerdata['height'][i][2])) for i in range(len(playerdata))]

# %%
playerdata['college'].fillna('No College', inplace = True)

# %%
playerdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1284 non-null   object
#  1   year_start  1284 non-null   int64
#  2   year_end    1284 non-null   int64
#  3   position    1284 non-null   object
#  4   height      1284 non-null   int64
#  5   weight      1284 non-null   float64
#  6   birth_date  1284 non-null   object
#  7   college     1284 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 80.4+ KB

# %%
statsdf.to_csv('./Data/playerdata_clean.csv', sep = ',', index=False)

# %%
playerdata.drop(columns = ['year_end', 'position', 'birth_date'], axis = 1, inplace = True)

# %%
playerdata
# Out:
#                      name  year_start  height  weight  \
# 0     Shareef Abdur-Rahim        1997      81   225.0
# 1            Alex Abrines        2017      78   190.0
# 2              Alex Acker        2006      77   185.0
# 3              Quincy Acy        2013      79   240.0
# 4            Hassan Adams        2007      76   220.0
# ...                   ...         ...     ...     ...
# 1279         Tyler Zeller        2013      84   253.0
# 1280    Derrick Zimmerman        2006      75   195.0
# 1281    Stephen Zimmerman        2017      84   240.0
# 1282          Paul Zipser        2017      80   215.0
# 1283          Ivica Zubac        2017      85   265.0
#
#                               college
# 0            University of California
# 1                          No College
# 2               Pepperdine University
# 3                   Baylor University
# 4               University of Arizona
# ...                               ...
# 1279     University of North Carolina
# 1280     Mississippi State University
# 1281  University of Nevada, Las Vegas
# 1282                       No College
# 1283                       No College
#
# [1284 rows x 5 columns]

# %%
playerdata.rename(columns={"name": "player"}, inplace = True)

# %%
statsdf.shape
# Out:
# (4318, 51)

# %%
statsdf = pd.merge(left = statsdf, right = playerdata, on = 'player')

# %%
statsdf.shape
# Out:
# (4327, 55)

# %%
statsdf[statsdf['player'] == 'Chris Johnson']
# Out:
#       year         player pos  age   tm     g   gs     mp   per    ts%  ...  \
# 3051  2011  Chris Johnson   C   25  TOT  14.0  1.0  138.0  10.2  0.554  ...
# 3052  2011  Chris Johnson   C   25  TOT  14.0  1.0  138.0  10.2  0.554  ...
# 3053  2012  Chris Johnson   C   26  TOT  27.0  0.0  175.0  10.8  0.557  ...
# 3054  2012  Chris Johnson   C   26  TOT  27.0  0.0  175.0  10.8  0.557  ...
# 3055  2013  Chris Johnson   C   27  MIN  30.0  0.0  284.0  18.4  0.650  ...
# 3056  2013  Chris Johnson   C   27  MIN  30.0  0.0  284.0  18.4  0.650  ...
# 3057  2013  Chris Johnson  SF   22  MEM   8.0  0.0  102.0  10.7  0.560  ...
# 3058  2013  Chris Johnson  SF   22  MEM   8.0  0.0  102.0  10.7  0.560  ...
# 3059  2014  Chris Johnson  SF   23  BOS  40.0  0.0  789.0  10.8  0.537  ...
# 3060  2014  Chris Johnson  SF   23  BOS  40.0  0.0  789.0  10.8  0.537  ...
#
#        stl   blk   tov    pf    pts  salary  year_start  height  weight  \
# 3051   3.0   9.0  10.0  21.0   33.0  164368        2011      73   210.0
# 3052   3.0   9.0  10.0  21.0   33.0  164368        2013      78   206.0
# 3053   6.0   9.0  15.0  33.0   55.0  762195        2011      73   210.0
# 3054   6.0   9.0  15.0  33.0   55.0  762195        2013      78   206.0
# 3055   7.0  28.0  13.0  49.0  117.0  508586        2011      73   210.0
# 3056   7.0  28.0  13.0  49.0  117.0  508586        2013      78   206.0
# 3057   4.0   0.0   3.0   5.0   29.0  508586        2011      73   210.0
# 3058   4.0   0.0   3.0   5.0   29.0  508586        2013      78   206.0
# 3059  27.0   4.0  22.0  63.0  250.0  916099        2011      73   210.0
# 3060  27.0   4.0  22.0  63.0  250.0  916099        2013      78   206.0
#
#                          college
# 3051  Louisiana State University
# 3052        University of Dayton
# 3053  Louisiana State University
# 3054        University of Dayton
# 3055  Louisiana State University
# 3056        University of Dayton
# 3057  Louisiana State University
# 3058        University of Dayton
# 3059  Louisiana State University
# 3060        University of Dayton
#
# [10 rows x 55 columns]

# %%
#Identify appropriate player by referring to position vs playerdata
statsdf.drop(index= [3052, 3054, 3056, 3057, 3059], axis = 0, inplace = True)

# %%
statsdf[statsdf['player'] == 'Chris Johnson']
# Out:
#       year         player pos  age   tm     g   gs     mp   per    ts%  ...  \
# 3051  2011  Chris Johnson   C   25  TOT  14.0  1.0  138.0  10.2  0.554  ...
# 3053  2012  Chris Johnson   C   26  TOT  27.0  0.0  175.0  10.8  0.557  ...
# 3055  2013  Chris Johnson   C   27  MIN  30.0  0.0  284.0  18.4  0.650  ...
# 3058  2013  Chris Johnson  SF   22  MEM   8.0  0.0  102.0  10.7  0.560  ...
# 3060  2014  Chris Johnson  SF   23  BOS  40.0  0.0  789.0  10.8  0.537  ...
#
#        stl   blk   tov    pf    pts  salary  year_start  height  weight  \
# 3051   3.0   9.0  10.0  21.0   33.0  164368        2011      73   210.0
# 3053   6.0   9.0  15.0  33.0   55.0  762195        2011      73   210.0
# 3055   7.0  28.0  13.0  49.0  117.0  508586        2011      73   210.0
# 3058   4.0   0.0   3.0   5.0   29.0  508586        2013      78   206.0
# 3060  27.0   4.0  22.0  63.0  250.0  916099        2013      78   206.0
#
#                          college
# 3051  Louisiana State University
# 3053  Louisiana State University
# 3055  Louisiana State University
# 3058        University of Dayton
# 3060        University of Dayton
#
# [5 rows x 55 columns]

# %%
statsdf[statsdf['player'] == 'Tony Mitchell']
# Out:
#       year         player pos  age   tm     g   gs    mp   per   ts%  ...  \
# 3882  2014  Tony Mitchell  SF   24  MIL   3.0  0.0  10.0  30.9  0.60  ...
# 3883  2014  Tony Mitchell  SF   24  MIL   3.0  0.0  10.0  30.9  0.60  ...
# 3884  2014  Tony Mitchell  SF   24  MIL   3.0  0.0  10.0  30.9  0.60  ...
# 3885  2014  Tony Mitchell  SF   24  MIL   3.0  0.0  10.0  30.9  0.60  ...
# 3886  2014  Tony Mitchell  PF   21  DET  21.0  0.0  79.0  18.1  0.54  ...
# 3887  2014  Tony Mitchell  PF   21  DET  21.0  0.0  79.0  18.1  0.54  ...
# 3888  2014  Tony Mitchell  PF   21  DET  21.0  0.0  79.0  18.1  0.54  ...
# 3889  2014  Tony Mitchell  PF   21  DET  21.0  0.0  79.0  18.1  0.54  ...
#
#       stl  blk  tov   pf   pts  salary  year_start  height  weight  \
# 3882  1.0  0.0  0.0  0.0   6.0  490180        2014      78   216.0
# 3883  1.0  0.0  0.0  0.0   6.0  490180        2014      80   235.0
# 3884  1.0  0.0  0.0  0.0   6.0   28834        2014      78   216.0
# 3885  1.0  0.0  0.0  0.0   6.0   28834        2014      80   235.0
# 3886  6.0  3.0  4.0  9.0  22.0  490180        2014      78   216.0
# 3887  6.0  3.0  4.0  9.0  22.0  490180        2014      80   235.0
# 3888  6.0  3.0  4.0  9.0  22.0   28834        2014      78   216.0
# 3889  6.0  3.0  4.0  9.0  22.0   28834        2014      80   235.0
#
#                         college
# 3882      University of Alabama
# 3883  University of North Texas
# 3884      University of Alabama
# 3885  University of North Texas
# 3886      University of Alabama
# 3887  University of North Texas
# 3888      University of Alabama
# 3889  University of North Texas
#
# [8 rows x 55 columns]

# %%
#Appropriate rows to drop identified by reviewing each player's wikipedia page
statsdf.drop(index= [3882, 3883, 3885, 3886, 3888, 3889], axis = 0, inplace = True)

# %%
statsdf[statsdf['player'] == 'Tony Mitchell']
# Out:
#       year         player pos  age   tm     g   gs    mp   per   ts%  ...  \
# 3884  2014  Tony Mitchell  SF   24  MIL   3.0  0.0  10.0  30.9  0.60  ...
# 3887  2014  Tony Mitchell  PF   21  DET  21.0  0.0  79.0  18.1  0.54  ...
#
#       stl  blk  tov   pf   pts  salary  year_start  height  weight  \
# 3884  1.0  0.0  0.0  0.0   6.0   28834        2014      78   216.0
# 3887  6.0  3.0  4.0  9.0  22.0  490180        2014      80   235.0
#
#                         college
# 3884      University of Alabama
# 3887  University of North Texas
#
# [2 rows x 55 columns]

# %%
statsdf[statsdf['player'] == 'Gary Payton']
# Out:
# Empty DataFrame
# Columns: [year, player, pos, age, tm, g, gs, mp, per, ts%, 3par, ftr, orb%, drb%, trb%, ast%, stl%, blk%, tov%, usg%, ows, dws, ws, ws/48, obpm, dbpm, bpm, vorp, fg, fga, fg%, 3p, 3pa, 3p%, 2p, 2pa, 2p%, efg%, ft, fta, ft%, orb, drb, trb, ast, stl, blk, tov, pf, pts, salary, year_start, height, weight, college]
# Index: []
#
# [0 rows x 55 columns]

# %%
statsdf[statsdf['player'] == 'Marcus Williams']
# Out:
#       year           player    pos  age   tm     g   gs     mp   per    ts%  \
# 2150  2008  Marcus Williams  PF-SF   21  TOT  11.0  0.0   36.0   6.8  0.250
# 2151  2008  Marcus Williams  PF-SF   21  TOT  11.0  0.0   36.0   6.8  0.250
# 2152  2009  Marcus Williams     PG   23  GSW   9.0  0.0   54.0   3.7  0.305
# 2153  2009  Marcus Williams     PG   23  GSW   9.0  0.0   54.0   3.7  0.305
# 2154  2009  Marcus Williams     PF   22  SAS   2.0  0.0    3.0  53.0  1.000
# 2155  2009  Marcus Williams     PF   22  SAS   2.0  0.0    3.0  53.0  1.000
# 2156  2010  Marcus Williams     PG   24  MEM  62.0  1.0  872.0  10.6  0.456
# 2157  2010  Marcus Williams     PG   24  MEM  62.0  1.0  872.0  10.6  0.456
#
#       ...   stl  blk   tov    pf    pts   salary  year_start  height  weight  \
# 2150  ...   1.0  1.0   0.0   3.0   10.0  1193090        2007      75   205.0
# 2151  ...   1.0  1.0   0.0   3.0   10.0  1193090        2008      79   205.0
# 2152  ...   1.0  1.0   4.0   6.0   12.0  1262520        2007      75   205.0
# 2153  ...   1.0  1.0   4.0   6.0   12.0  1262520        2008      79   205.0
# 2154  ...   0.0  0.0   0.0   1.0    4.0  1262520        2007      75   205.0
# 2155  ...   0.0  0.0   0.0   1.0    4.0  1262520        2008      79   205.0
# 2156  ...  32.0  1.0  74.0  43.0  269.0   855189        2007      75   205.0
# 2157  ...  32.0  1.0  74.0  43.0  269.0   855189        2008      79   205.0
#
#                         college
# 2150  University of Connecticut
# 2151      University of Arizona
# 2152  University of Connecticut
# 2153      University of Arizona
# 2154  University of Connecticut
# 2155      University of Arizona
# 2156  University of Connecticut
# 2157      University of Arizona
#
# [8 rows x 55 columns]

# %%
statsdf.drop(index= [2150, 2153, 2154, 2157], axis = 0, inplace = True)

# %%
statsdf[statsdf['player'] == 'Marcus Williams']
# Out:
#       year           player    pos  age   tm     g   gs     mp   per    ts%  \
# 2151  2008  Marcus Williams  PF-SF   21  TOT  11.0  0.0   36.0   6.8  0.250
# 2152  2009  Marcus Williams     PG   23  GSW   9.0  0.0   54.0   3.7  0.305
# 2155  2009  Marcus Williams     PF   22  SAS   2.0  0.0    3.0  53.0  1.000
# 2156  2010  Marcus Williams     PG   24  MEM  62.0  1.0  872.0  10.6  0.456
#
#       ...   stl  blk   tov    pf    pts   salary  year_start  height  weight  \
# 2151  ...   1.0  1.0   0.0   3.0   10.0  1193090        2008      79   205.0
# 2152  ...   1.0  1.0   4.0   6.0   12.0  1262520        2007      75   205.0
# 2155  ...   0.0  0.0   0.0   1.0    4.0  1262520        2008      79   205.0
# 2156  ...  32.0  1.0  74.0  43.0  269.0   855189        2007      75   205.0
#
#                         college
# 2151      University of Arizona
# 2152  University of Connecticut
# 2155      University of Arizona
# 2156  University of Connecticut
#
# [4 rows x 55 columns]

# %%
statsdf[statsdf['player'] == 'Chris Wright']
# Out:
#       year        player pos  age   tm     g   gs     mp   per    ts%  ...  \
# 3475  2012  Chris Wright  SF   23  GSW  24.0  1.0  186.0  18.6  0.597  ...
# 3476  2012  Chris Wright  SF   23  GSW  24.0  1.0  186.0  18.6  0.597  ...
# 3477  2013  Chris Wright  SG   23  DAL   3.0  0.0    4.0  -1.9  0.500  ...
# 3478  2013  Chris Wright  SG   23  DAL   3.0  0.0    4.0  -1.9  0.500  ...
# 3479  2014  Chris Wright  SF   25  MIL   8.0  0.0  126.0  16.5  0.577  ...
# 3480  2014  Chris Wright  SF   25  MIL   8.0  0.0  126.0  16.5  0.577  ...
#
#       stl   blk  tov    pf   pts  salary  year_start  height  weight  \
# 3475  7.0  13.0  8.0  22.0  70.0  473604        2012      80   226.0
# 3476  7.0  13.0  8.0  22.0  70.0  473604        2013      73   210.0
# 3477  0.0   0.0  1.0   0.0   2.0   27859        2012      80   226.0
# 3478  0.0   0.0  1.0   0.0   2.0   27859        2013      73   210.0
# 3479  7.0   5.0  5.0  17.0  48.0  139212        2012      80   226.0
# 3480  7.0   5.0  5.0  17.0  48.0  139212        2013      73   210.0
#
#                     college
# 3475   University of Dayton
# 3476  Georgetown University
# 3477   University of Dayton
# 3478  Georgetown University
# 3479   University of Dayton
# 3480  Georgetown University
#
# [6 rows x 55 columns]

# %%
statsdf.drop(index= [3476, 3477, 3480], axis = 0, inplace = True)

# %%
statsdf[statsdf['player'] == 'Chris Wright']
# Out:
#       year        player pos  age   tm     g   gs     mp   per    ts%  ...  \
# 3475  2012  Chris Wright  SF   23  GSW  24.0  1.0  186.0  18.6  0.597  ...
# 3478  2013  Chris Wright  SG   23  DAL   3.0  0.0    4.0  -1.9  0.500  ...
# 3479  2014  Chris Wright  SF   25  MIL   8.0  0.0  126.0  16.5  0.577  ...
#
#       stl   blk  tov    pf   pts  salary  year_start  height  weight  \
# 3475  7.0  13.0  8.0  22.0  70.0  473604        2012      80   226.0
# 3478  0.0   0.0  1.0   0.0   2.0   27859        2013      73   210.0
# 3479  7.0   5.0  5.0  17.0  48.0  139212        2012      80   226.0
#
#                     college
# 3475   University of Dayton
# 3478  Georgetown University
# 3479   University of Dayton
#
# [3 rows x 55 columns]

# %%
statsdf.reset_index(drop = True, inplace = True)

# %%
#export the merged stats with additional player details
statsdf.to_csv('./Data/stats_enriched.csv', sep = ',', index=False)
